# %%
import os, sys, glob, re
import datetime as dt
import numpy as np
from calendar import monthrange
from matplotlib.dates import date2num, num2date
# import h5py
from sklearn import decomposition
import nimfa
from scipy import signal

sys.path.insert(0,'/home/wu-jung/code_git/mi-instrument')
from mi.instrument.kut.ek60.ooicore.zplsc_b import *
# from concat_raw import get_num_days_pings, get_data_from_h5
# from echogram_decomp import find_nearest_time_idx,reshape_into_3freq,reshape_into_1freq,\
#     sep_into_freq,plot_decomp_v,plot_decomp_transform
from db_diff import *

import matplotlib.pyplot as plt
# from modest_image import imshow
# from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# %matplotlib inline

# %%
date_start = dt.date(2015,8,17)
date_end = dt.date(2015,10,17)
date_wanted = [(date_start+dt.timedelta(days=xx)).strftime('%Y%m%d') for xx in range((date_end-date_start).days + 1)]

# %%
data_path = '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/'
save_path = '/media/wu-jung/wjlee_apl_2/ooi_zplsc_new/'
save_fname = '%s-%s' % (date_start.strftime('%Y%m%d'),date_end.strftime('%Y%m%d'))

# %%
# Set param
hour_all = range(24)
min_all = range(20)
sec_all = range(0,60,5)
ping_per_day = len(hour_all)*len(min_all)*len(sec_all)

ping_bin_range = 40
depth_bin_range = 10
tvg_correction_factor = 2

# %%
dd= date_wanted[60]
# load files and get calibration params
fname = glob.glob(os.path.join(data_path,'OOI-D%s*.raw' %dd))[0]
particle_data, data_times, power_data, freq, bin_size, config_header, config_transducer = \
    parse_echogram_file(fname)
cal_params = get_cal_params(power_data,particle_data,config_header,config_transducer)

# swap sequence of 120 kHz and 38 kHz cal_params and data
cal_params = [cal_params[fn] for fn in [1,0,2]]
power_data = get_power_data_mtx(power_data,freq)

# clean data
Sv_raw_tmp = np.ma.empty((power_data.shape))
Sv_corr_tmp = np.ma.empty((power_data.shape))
Sv_noise_tmp = np.ma.empty((power_data.shape[0:2]))
for fn in range(power_data.shape[0]):
    noise_est,ping_bin_num = get_noise(power_data[fn,:,:],bin_size,ping_bin_range,depth_bin_range)
    Sv_raw_tmp[fn,:,:],Sv_corr_tmp[fn,:,:],Sv_noise_tmp[fn,:] = \
            remove_noise(power_data[fn,:,:],cal_params[fn],noise_est.min(),ping_bin_range,tvg_correction_factor)

# set up indexing to get wanted pings
dd = dt.datetime.strptime(dd,'%Y%m%d')
time_wanted = [dt.datetime(dd.year,dd.month,dd.day,hh,mm,ss) for hh in hour_all for mm in min_all for ss in sec_all]
idx_wanted = [find_nearest_time_idx(data_times,tt,2) for tt in time_wanted]
notnanidx = np.argwhere(~np.isnan(idx_wanted)).flatten()
notnanidx_in_all = np.array(idx_wanted)[notnanidx].astype(int)

# get data to to saved
Sv_raw = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],ping_per_day))
Sv_corr = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],ping_per_day))
Sv_noise = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],1))

Sv_raw[:,:,notnanidx] = Sv_raw_tmp[:,:,notnanidx_in_all]
Sv_corr[:,:,notnanidx] = Sv_corr_tmp[:,:,notnanidx_in_all]
Sv_noise[:,:,0] = Sv_noise_tmp
ping_time = date2num(time_wanted)

idx_save_mask = np.argwhere(np.isnan(idx_wanted))
Sv_raw[:,:,idx_save_mask] = np.ma.masked
Sv_raw[:,:,idx_save_mask].mask = True
Sv_corr[:,:,idx_save_mask] = np.ma.masked
Sv_corr[:,:,idx_save_mask].mask = True

MVBS = get_MVBS(Sv_corr,bin_size,ping_bin_range,depth_bin_range=5)
# Out:
# 2017-10-18 07:43:20,935 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151016-T000000.raw'

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_corr[0,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
idx_bkg = np.nonzero(Sv_corr<-40)

# %%
Sv_bkg = np.ma.copy(Sv_corr)

# %%
Sv_bkg[idx_bkg] = np.nan
Sv_bkg[idx_bkg].mask= True

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_bkg[0,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)
plt.colorbar()

# %%
Sv_bkg_medfilt = signal.medfilt2d(Sv_bkg[0,:,:],kernel_size=5)

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_bkg_medfilt,aspect='auto',cmap=e_cmap,norm=e_norm)
plt.colorbar()

# %%
idx_large = np.nonzero(Sv_corr>-45)

# %%
Sv_corr[idx_large] = np.ma.masked

# %%
idx_large
# Out:
# (array([0, 0, 0, ..., 2, 2, 2]),
#  array([   0,    0,    0, ..., 1045, 1045, 1045]),
#  array([   0,    1,    2, ..., 5502, 5508, 5512]))

# %%
idx_large_array=np.array(idx_large)

# %%
idx_large_array
# Out:
# array([[   0,    0,    0, ...,    2,    2,    2],
#        [   0,    0,    0, ..., 1045, 1045, 1045],
#        [   0,    1,    2, ..., 5502, 5508, 5512]])

# %%
type(Sv_corr)
# Out:
# numpy.ma.core.MaskedArray

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_corr[0,:,0:400],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_corr[0,:,0:400],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
fig,ax = plt.subplots(2,1,figsize=(22,10))
ax[0].imshow(Sv_corr[0,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)
ax[1].imshow(MVBS[0,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
Sv_corr_med0 = signal.medfilt2d(Sv_corr[0,:,:],kernel_size=9)

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_corr_med0,aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
plt.subplots(figsize=(22,5))
plt.imshow(Sv_corr[0,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
for iD,dd in zip(range(len(date_wanted)),date_wanted):

    # load files and get calibration params
    fname = glob.glob(os.path.join(data_path,'OOI-D%s*.raw' %dd))[0]
    particle_data, data_times, power_data, freq, bin_size, config_header, config_transducer = \
        parse_echogram_file(fname)
    cal_params = get_cal_params(power_data,particle_data,config_header,config_transducer)

    # swap sequence of 120 kHz and 38 kHz cal_params and data
    cal_params = [cal_params[fn] for fn in [1,0,2]]
    power_data = get_power_data_mtx(power_data,freq)

    # clean data
    Sv_raw_tmp = np.ma.empty((power_data.shape))
    Sv_corr_tmp = np.ma.empty((power_data.shape))
    Sv_noise_tmp = np.ma.empty((power_data.shape[0:2]))
    for fn in range(power_data.shape[0]):
        noise_est,ping_bin_num = get_noise(power_data[fn,:,:],bin_size,ping_bin_range,depth_bin_range)
        Sv_raw_tmp[fn,:,:],Sv_corr_tmp[fn,:,:],Sv_noise_tmp[fn,:] = \
                remove_noise(power_data[fn,:,:],cal_params[fn],noise_est.min(),ping_bin_range,tvg_correction_factor)

    # set up indexing to get wanted pings
    dd = dt.datetime.strptime(dd,'%Y%m%d')
    time_wanted = [dt.datetime(dd.year,dd.month,dd.day,hh,mm,ss) for hh in hour_all for mm in min_all for ss in sec_all]
    idx_wanted = [find_nearest_time_idx(data_times,tt,2) for tt in time_wanted]
    notnanidx = np.argwhere(~np.isnan(idx_wanted)).flatten()
    notnanidx_in_all = np.array(idx_wanted)[notnanidx].astype(int)

    # get data to to saved
    Sv_raw = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],ping_per_day))
    Sv_corr = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],ping_per_day))
    Sv_noise = np.ma.empty((Sv_raw.shape[0],Sv_raw.shape[1],1))
    
    Sv_raw[:,:,notnanidx] = Sv_raw_tmp[:,:,notnanidx_in_all]
    Sv_corr[:,:,notnanidx] = Sv_corr_tmp[:,:,notnanidx_in_all]
    Sv_noise[:,:,0] = Sv_noise_tmp
    ping_time = date2num(time_wanted)

    idx_save_mask = np.argwhere(np.isnan(idx_wanted))
    Sv_raw[:,:,idx_save_mask] = np.ma.masked
    Sv_corr[:,:,idx_save_mask] = np.ma.masked
    
    # save into h5 file
    sz = Sv_raw.shape
    f = h5py.File(os.path.join(save_path,'%s_Sv.h5' %save_fname),"a")
    if "Sv_raw" in f:  # if file alread exist and contains Sv mtx
        print '-- H5 file exists, append new data mtx...'
        # append new data
        sz_exist = f['Sv_raw'].shape  # shape of existing Sv mtx
        f['Sv_raw'].resize((sz_exist[0],sz_exist[1],sz_exist[2]+sz[2]))
        f['Sv_raw'][:,:,sz_exist[2]:] = Sv_raw
        f['Sv_corr'].resize((sz_exist[0],sz_exist[1],sz_exist[2]+sz[2]))
        f['Sv_corr'][:,:,sz_exist[2]:] = Sv_corr
        f['Sv_noise'].resize((sz_exist[0],sz_exist[1],sz_exist[2]+1))
        f['Sv_noise'][:,:,sz_exist[2]:] = Sv_noise
        f['ping_time'].resize((sz_exist[2]+sz[2],))
        f['ping_time'][sz_exist[2]:] = ping_time
    else:
        print '-- New H5 file, create new dataset...'
        # create dataset and save
        f.create_dataset("Sv_raw", sz, maxshape=(sz[0],sz[1],None), data=Sv_raw, chunks=True)
        f.create_dataset("Sv_corr", sz, maxshape=(sz[0],sz[1],None), data=Sv_corr, chunks=True)
        f.create_dataset("Sv_noise", (Sv_raw.shape[0],Sv_raw.shape[1],1), maxshape=(sz[0],sz[1],None), data=Sv_noise, chunks=True)
        f.create_dataset("ping_time", (sz[2],), maxshape=(None,), data=ping_time, chunks=True)
        f.create_dataset("depth_bin_size",data=bin_size)
    f.close()

    # get MVBS
    MVBS = get_MVBS(Sv_corr,bin_size,ping_bin_range,depth_bin_range=5)
    
    # save into h5 file
    sz = MVBS.shape
    ping_time_MVBS = ping_time[0::ping_bin_range]  # get ping time every ping_bin_range for MVBS
    
    f = h5py.File(os.path.join(save_path,'%s_MVBS.h5' %save_fname),"a")
    if "MVBS" in f:  # if file alread exist and contains Sv mtx
        print '-- H5 file exists, append new data mtx...'
        # append new data
        sz_exist = f['MVBS'].shape  # shape of existing Sv mtx
        f['MVBS'].resize((sz_exist[0],sz_exist[1],sz_exist[2]+sz[2]))
        f['MVBS'][:,:,sz_exist[2]:] = MVBS
        f['ping_time'].resize((sz_exist[2]+sz[2],))
        f['ping_time'][sz_exist[2]:] = ping_time_MVBS
    else:
        print '-- New H5 file, create new dataset...'
        # create dataset and save
        f.create_dataset("MVBS", sz, maxshape=(sz[0],sz[1],None), data=MVBS, chunks=True)
        f.create_dataset("ping_time", (sz[2],), maxshape=(None,), data=ping_time_MVBS, chunks=True)
        f.create_dataset("depth_bin_size",data=depth_bin_range)
    f.close()
# Out:
# 2017-10-14 23:03:08,018 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150817-T000000.raw'
# -- New H5 file, create new dataset...
# -- New H5 file, create new dataset...
# 2017-10-14 23:03:38,542 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150818-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:04:08,485 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150819-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:04:37,956 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150820-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:05:08,739 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150821-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:05:46,072 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150822-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:06:17,024 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150823-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:06:48,155 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150824-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:07:18,798 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150825-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:07:58,010 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150826-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:08:46,859 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150827-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:09:31,772 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150828-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:10:22,054 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150829-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:10:57,304 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150830-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:11:37,317 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150831-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:12:15,771 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150901-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:12:53,308 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150902-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:13:35,784 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150903-T000000.raw'
# -- H5 file exists, append new data mtx...
# /home/wu-jung/anaconda3/envs/py27/lib/python2.7/site-packages/numpy/ma/core.py:6457: RuntimeWarning: overflow encountered in power
#   result = np.where(m, fa, umath.power(fa, fb)).view(basetype)
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:14:18,700 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150904-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:14:56,778 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150905-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:15:40,971 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150906-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:16:21,978 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150907-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:17:02,754 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150908-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:17:38,779 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150909-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:18:17,338 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150910-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:18:54,412 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150911-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:19:25,375 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150912-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:20:03,635 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150913-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:20:33,981 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150914-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:21:04,959 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150915-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:21:37,842 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150916-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:22:12,406 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150917-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:22:43,941 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150918-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:23:15,857 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150919-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:23:50,937 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150920-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:24:22,428 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150921-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:24:58,997 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150922-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:25:31,203 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150923-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:26:04,614 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150924-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:26:35,691 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150925-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:27:10,575 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150926-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:27:41,243 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150927-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:28:18,016 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150928-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:28:55,463 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150929-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:29:32,191 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20150930-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:30:10,796 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151001-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:30:47,655 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151002-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:31:23,541 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151003-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:32:00,246 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151004-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:32:38,513 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151005-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:33:13,534 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151006-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:33:48,464 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151007-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:34:24,686 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151008-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:34:59,835 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151009-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:35:32,851 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151010-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:36:08,229 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151011-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:36:41,383 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151012-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:37:12,031 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151013-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:37:44,504 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151014-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:38:16,764 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151015-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:38:47,424 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151016-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...
# 2017-10-14 23:39:17,877 INFO     mi.instrument.kut.ek60.ooicore.zplsc_b Begin processing echogram data: '/media/wu-jung/wjlee_apl_2/ooi_zplsc_600m/OOI-D20151017-T000000.raw'
# -- H5 file exists, append new data mtx...
# -- H5 file exists, append new data mtx...

# %% [markdown]
# ## Load MVBS data and process

# %%
f = h5py.File(os.path.join(save_path,'%s_MVBS.h5' %save_fname),"r")

# %%
MVBS = np.array(f['MVBS'])

# %%
fig,ax = plt.subplots(3,1,figsize=(15,9))
ax[0].imshow(MVBS[0,:,0:],aspect='auto',cmap=e_cmap,norm=e_norm)
ax[1].imshow(MVBS[1,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)
ax[2].imshow(MVBS[2,:,:],aspect='auto',cmap=e_cmap,norm=e_norm)

# %%
fig,ax = plt.subplots(3,1,figsize=(15,9))
ax[0].imshow(MVBS[0,:,1000*2+np.arange(1000)].T,aspect='auto',cmap=e_cmap,norm=e_norm)
ax[1].imshow(MVBS[1,:,1000*2+np.arange(1000)].T,aspect='auto',cmap=e_cmap,norm=e_norm)
ax[2].imshow(MVBS[2,:,1000*2+np.arange(1000)].T,aspect='auto',cmap=e_cmap,norm=e_norm)

# %% [markdown]
# ## NMF

# %% [markdown]
# ### Linear domain

# %%
mvbs = 10**(MVBS/10)

# %%
mvbs.shape
# Out:
# (3, 40, 8928)

# %%
ping_per_day_mvbs = ping_per_day/ping_bin_range

# %%
ping_per_day_mvbs
# Out:
# 144

# %%
mvbs_3freq = np.array([mvbs[ff,:,:].T.reshape((-1,ping_per_day_mvbs*mvbs.shape[1])) for ff in range(3)])
mvbs_long = mvbs_3freq.swapaxes(0,1).reshape((-1,ping_per_day_mvbs*mvbs.shape[1]*3))

# %%
mvbs_long.shape
# Out:
# (62, 17280)

# %%
n_comp = 2
nmf_min = decomposition.NMF(n_components=n_comp)
W_nmf = nmf_min.fit_transform(mvbs_long)
H_nmf = nmf_min.components_

# %%
V_nmf = H_nmf.reshape((n_comp,3*ping_per_day_mvbs,-1)).swapaxes(1,2)

# %%
fig,ax=plt.subplots(n_comp,1,sharey=True,figsize=(22,10))
for c in range(n_comp):
#     cmean = np.mean(V_nmf[c,:,:])
#     cstd = np.std(V_nmf[c,:,:])
#     cmin = max((0,cmean-2*cstd))
#     cmax = min((np.max(V_nmf[c,:,:]),cmean+4*cstd))
    ax[c].imshow(10*np.log10(V_nmf[c,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
    ax[c].set_xticklabels(['38k','120k','200k'])
    ax[c].tick_params('both', length=0)
#     ax[c].set_yticks((0,depth_bin_num))
#     ax[c].set_yticklabels([str(np.int_(depth_min)),str(depth_max)])
# Out:
# /home/wu-jung/anaconda3/envs/py27/lib/python2.7/site-packages/ipykernel/__main__.py:7: RuntimeWarning: divide by zero encountered in log10

# %%
plt.figure(figsize=(22,3))
labels = [str(x) for x in range(n_comp)]
for w, label in zip(W_nmf.T, labels):
    plt.plot(w, label=label)
plt.legend()

# %% [markdown]
# ## Log domain

# %%
MVBS_3freq = np.array([MVBS[ff,:,:].T.reshape((-1,ping_per_day_mvbs*MVBS.shape[1])) for ff in range(3)])
MVBS_long = MVBS_3freq.swapaxes(0,1).reshape((-1,ping_per_day_mvbs*MVBS.shape[1]*3))

# %%
n_comp = 5
M_nmf_min = decomposition.NMF(n_components=n_comp)
M_W_nmf = M_nmf_min.fit_transform(MVBS_long-MVBS_long.min())
M_H_nmf = M_nmf_min.components_

# %%
M_V_nmf = M_H_nmf.reshape((5,3*ping_per_day_mvbs,-1)).swapaxes(1,2)

# %%
fig,ax=plt.subplots(5,1,sharey=True,figsize=(22,10))
for c in range(n_comp):
    ax[c].imshow(M_V_nmf[c,:,:],aspect='auto')

# %%
plt.figure(figsize=(22,3))
labels =['1', '2', '3','4','5']
for w, label in zip(M_W_nmf.T, labels):
    plt.plot(w, label=label)
plt.legend()

# %% [markdown]
# ## Freq-differencing

# %%
Sv_1 = MVBS[2,:,:]
Sv_2 = MVBS[0,:,:]

yes_1 = ~np.isnan(Sv_1)
yes_2 = ~np.isnan(Sv_2)
Sv_diff_12 = Sv_1 - Sv_2
Sv_diff_12[yes_1 & ~yes_2] = np.inf
Sv_diff_12[~yes_1 & yes_2] = -np.inf

idx_fish = (np.isneginf(Sv_diff_12) | (Sv_diff_12<-2)) & (Sv_diff_12>-16)
idx_fish_2 = (np.isneginf(Sv_diff_12) | (Sv_diff_12<-2))
idx_zoop = np.isposinf(Sv_diff_12) | (Sv_diff_12>-2)
idx_other = Sv_diff_12<-16

# %%
fig,(ax0,ax1,ax2) = plt.subplots(ncols=3,figsize=(22,5))
im0 = ax0.imshow(np.ma.masked_where(~idx_fish,MVBS[0,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im0,ax=ax0)
ax0.set_title('Fish region, 38 kHz')
im1 = ax1.imshow(np.ma.masked_where(~idx_fish,MVBS[1,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im1,ax=ax1)
ax1.set_title('Fish region, 120 kHz')
im2 = ax2.imshow(np.ma.masked_where(~idx_fish,MVBS[2,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im2,ax=ax2)
ax2.set_title('Fish region, 200 kHz')

# %%
fig,(ax0,ax1,ax2) = plt.subplots(ncols=3,figsize=(22,5))
im0 = ax0.imshow(np.ma.masked_where(~idx_zoop,MVBS[0,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im0,ax=ax0)
ax0.set_title('Zoop region, 38 kHz')
im1 = ax1.imshow(np.ma.masked_where(~idx_zoop,MVBS[1,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im1,ax=ax1)
ax1.set_title('Zoop region, 120 kHz')
im2 = ax2.imshow(np.ma.masked_where(~idx_zoop,MVBS[2,:,:]),aspect='auto',cmap=e_cmap,norm=e_norm)
fig.colorbar(im2,ax=ax2)
ax2.set_title('Zoop region, 200 kHz')
