# %% [markdown]
# # Notebook for plotting figures
#
# This notebook is for generating and saving plots. See the other notebook `2019-10-22_oceans-conf-paper-plot.ipynb` for details of analysis.

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.dates as mdates
import datetime
import h5py
import pandas as pd
import xarray as xr
import tensorly as tl

# %% [markdown]
# ## Load and inspect data

# %%
# print('There are a total of %d pings per hour.' % (20*60/5))  # Number of pings per hour

# %% [markdown]
# ### Calibrated MVBS data
#
# Here we first inspect the calibrated mean volume backscattering strength (MVBS, or $\overline{\textrm{S}_\textrm{V}}$) already pre-processed from the raw data.
# The raw data were obtained from the Ocean Observatories Initiative (OOI) Raw Data
# Archive, from the Oregon Offshore Cabled Shallow Profiler Mooring (CE04OSPS).
# All other info can be found in the paper.

# %%
# Set up paths
MVBS_raw_path = '../sample_data/'
MVBS_raw_fname = '20150817-20151017_MVBS.h5'
fig_save_path = './figs_2019_paper/'

# %%
# Load raw MVBS data
f_raw = h5py.File(os.path.join(MVBS_raw_path,MVBS_raw_fname),'r')
MVBS_raw = np.array(f_raw['MVBS'])
depth_bin_size = np.array(f_raw['depth_bin_size'])
ping_time = np.array(f_raw['ping_time'])
f_raw.close()

# %% [markdown]
# Let's first inspect the dimension of the data:

# %%
echoes_mvbs = []
for f in range(3):
    echoes_mvbs.append(MVBS_raw[f,37:0:-1,:])

# %% [markdown]
# Let's contruct an xarray DataArray for the MVBS data to make plotting easier:

# %%
frequency = np.array([38000,120000,200000])
p_time = pd.to_datetime(mdates.num2date(ping_time)).tz_convert(None)
depth = (np.arange(37)+1)*depth_bin_size
MVBS = xr.DataArray(np.array(echoes_mvbs), 
                    coords=[('frequency', frequency), 
                            ('depth', depth), 
                            ('ping_time', p_time)])

# %%
def plot_3_echograms(da):
    fig,ax = plt.subplots(3,1,figsize=(14,5),sharex=True)
    im = da.sel(frequency=38000).\
        plot(ax=ax[0], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    da.sel(frequency=120000).\
        plot(ax=ax[1], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    da.sel(frequency=200000).\
        plot(ax=ax[2], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    ax[0].set_xlabel('')
    ax[1].set_xlabel('')
    ax[2].xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))

    ax[2].set_xlabel('Time', fontsize=14)
    plt.setp(ax[2].get_xticklabels(), rotation=0, horizontalalignment='center')

    for c in range(3):
        ax[c].set_title('')
        ax[c].tick_params(labelsize=12)
        ax[c].set_ylabel('')
        ax[c].annotate('%d kHz'%(frequency[c]/1000), 
                       xy=(0.015,0.15), xycoords='axes fraction', 
                       fontsize=14, color='k', 
                       bbox=dict(facecolor='w', edgecolor=None, alpha=0.8))
    
    ax[1].set_ylabel('Depth (m)', fontsize=14)
    
    plt.subplots_adjust(hspace=0.1)

    fig.subplots_adjust(right=0.95)
    cbar_ax = fig.add_axes([0.96, 0.125, 0.01, 0.755])  # [left, bottom, width, height]
    cbar = fig.colorbar(im, cax=cbar_ax)
    cbar.set_ticks(np.arange(-80, -39, 10))
    cbar.ax.get_yaxis().labelpad = 5
    cbar.ax.set_ylabel('Sv (dB)', rotation=90, fontsize=14)

    plt.show()
    return fig

# %%
fig = plot_3_echograms(MVBS)
fig.savefig(os.path.join(fig_save_path,'MVBS.png'), 
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# When assembling the DataArrat, note that we inverted the second dimension (depth) of the loaded data. This is because the sonar was upward-looking from an underwater platform and the echo time series was recorded from the source location, so the depth dimension was inverted. We only plot the first 37 depth bins because the last 3 bins contains very strong scattering from the sea surface that can dominate the decomposition. The surface scattering also include signatures from the tidal cycles that have a different periodicity than the daylight cycles on which our decomposition is structured.

# %% [markdown]
# ### MVBS cleaned using PCP

# %% [markdown]
# Seeing the many noisy echo patches in the original calibrated MVBS data, we employed Principal Component Pursuit (PCP) to separate the noisy component from the low-rank component before applying tensor decomposition. PCP takes some time to run, so here we will proceed by loading the low-rank component from PCP that has been calculated elsewhere.

# %%
# Load PCP-cleaned MVBS data
MVBS_pcp_path = '../sample_data'
MVBS_pcp_fname = '20150817-20151017_MVBS_PCPcleaned.h5'
f_pcp = h5py.File(os.path.join(MVBS_pcp_path,MVBS_pcp_fname),'r')

# Load only low-rank data
L = np.array(f_pcp['L'])
L_sep = np.array(f_pcp['L_sep'])
depth_bin_size = np.array(f_pcp['depth_bin_size'])
ping_per_day_mvbs = np.array(f_pcp['ping_per_day_mvbs'])
ping_time = np.array(f_pcp['ping_time'])
f_pcp.close()

# %% [markdown]
# The low-rank data is organized with dimension `frequency` x `day of observation` x `depth` x `chunk of pings within day`.

# %%
L_sep.shape
# Out:
# (3, 62, 37, 144)

# %%
echoes_low_rank = []
for f in range(3):
    echoes_low_rank.append(tl.unfold(tl.tensor(L_sep[f,:,:,:].squeeze()),mode=1)[::-1,:])

# %% [markdown]
# The same as before, we construct an xarray DataArray to make plotting easier:

# %%
frequency = np.array([38000,120000,200000])
p_time = pd.to_datetime(mdates.num2date(ping_time)).tz_convert(None)
depth = (np.arange(37)+1)*depth_bin_size
MVBS_pcp = xr.DataArray(np.array(echoes_low_rank), 
                        coords=[('frequency', frequency), 
                                ('depth', depth), 
                                ('ping_time', p_time)])

# %%
fig = plot_3_echograms(MVBS_pcp)
fig.savefig(os.path.join(fig_save_path,'MVBS_pcp.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Data decimation
#
# After some trial-and-error, we found out that tensor decomposition takes quite a bit of memory and that we can more efficiently run the decomposition by decimating the low-rank data by averaging 6 tiles of MVBS data, which effectively reduce the data to 1 observation per hour for each depth bin.

# %%
# Average across time of day columns
tod_num = 6
L_sep_reduce = np.empty(np.hstack((np.array(L_sep.shape[:3]),int(L_sep.shape[-1]/tod_num))))
for i in np.arange(int(L_sep.shape[-1]/tod_num)):
    L_sep_reduce[:,:,:,i] = np.mean(L_sep[:,:,:,i*tod_num+np.arange(tod_num)],axis=3)

# %%
L_sep_reduce.shape
# Out:
# (3, 62, 37, 24)

# %% [markdown]
# Similar to before, let's construct a DataArray for the decimated data:

# %%
echoes_low_rank_reduce = []
for f in range(3):
    echoes_low_rank_reduce.append(tl.unfold(tl.tensor(L_sep_reduce[f,:,:,:].squeeze()),mode=1)[::-1,:])
    
frequency = np.array([38000,120000,200000])
p_time_reduce = pd.to_datetime(mdates.num2date(ping_time[::tod_num])).tz_convert(None)
depth = (np.arange(37)+1)*depth_bin_size
MVBS_pcp_reduce = xr.DataArray(np.array(echoes_low_rank_reduce), 
                               coords=[('frequency', frequency), 
                                       ('depth', depth), 
                                       ('ping_time', p_time_reduce)])

# %% [markdown]
# On the grand scale the decimated data look very similar to without averaging over the pings:

# %%
fig = plot_3_echograms(MVBS_pcp_reduce)
fig.savefig(os.path.join(fig_save_path,'MVBS_pcp_reduce.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# But obviously the effects of decimation are much more prominent when you look at only a smaller number of days:

# %% [markdown]
# First we look at the pcp-cleaned MVBS data for the first 10 days:

# %%
fig = plot_3_echograms(MVBS_pcp.sel(ping_time=slice('2015-08-16','2015-09-06')))

# %% [markdown]
# And when we compare it with the decimated data:

# %%
fig = plot_3_echograms(MVBS_pcp_reduce.sel(ping_time=slice('2015-08-16','2015-09-06')))

# %% [markdown]
# The basic features of the echograms are preserved in the decimated data, but the effects of quantization is also clearly visible.

# %% [markdown]
# ## Restructuring data for tensor decomposition
#
# Before performing tensor decomposition we need to reshape the low-rank data matrix into a tensor with all pixels within the daily echograms concatenated into a tall vector.
#
# This is because for decomposition, we actually don't want to decompose along each of the `frequency`, `day of observation`, `depth`, `chunk of pings within day` dimensions. Doing so will force decomposition along `depth` and `chunk of pings within day` separately, when in reality an organism group's movement in the water column (along `depth`) is coupled with the time of day (along `chunk of pings within day`).
#
# Another way to think about this is that, for the Kruskal form of decomposition, it is not possible for a single component to capture the diel vertical migration (DVM), since the DVM pattern cannot be produced by an outer product of two vectors. It therefore makes more sense to go back to treate daily echogramss as images as it was done for NMF decomposition. The difference is that here we can arrange data from different frequencies along one specific dimension instead of concatenating them together.

# %% [markdown]
# ### Reshaping the data matrix

# %% [markdown]
# We first inspect the dimension of the reduced low-rank data matrix:

# %%
L_sep_reduce.shape
# Out:
# (3, 62, 37, 24)

# %% [markdown]
# We then reshape this matrix to one that collapse all pixels within a daily echogram into a long vector:

# %%
L_sep_reduce_reshape = L_sep_reduce.reshape((3,62,37*24))

# %% [markdown]
# Let's plot the reshaped matrix out to check if it makes sense:

# %%
# Plot the first frequency of the reshaped reduced low-rank data matrix
fig = plt.figure(figsize=(6,8))
plt.imshow(tl.unfold(tl.tensor(L_sep_reduce_reshape[0,:,:]),mode=1)[::-1,:],
           vmin=-80, vmax=-40,
           aspect='auto',cmap='Spectral_r')
plt.xlabel('Day of observation',fontsize=14)
plt.ylabel('Pixels within daily echogram',fontsize=14)
plt.show()

# %% [markdown]
# This picture makes sense: The horizontal stripes within each column correspond with the number of depth bins for each ping. As organism vertical movements across consecutive days are typically smoothly-varying, the color changes smoothly along the horizontal dimension (`Day of observation`).

# %% [markdown]
# ## Kruskal tensor decomposition
#
# Now let's try to decompose the reshaped and reduced low-rank matrix using the Kruskal form of tensor decomposition. The decomposition will be along three dimensions: `frequency`, `day of observation` and `pixels within daily echogram`.

# %%
# kruskal decomposition is parafac in tensorly
from tensorly.decomposition import parafac
from tensorly.tenalg import kronecker, khatri_rao

# %%
sonar_tensor = tl.tensor(L_sep_reduce_reshape)

# %% [markdown]
# ### Rank=3
#
# We set rank=3 because we are limited by the number of frequencies we have in the data set. Note that in order to run the non-negative version of Kruskal decomposition we need to make all observations positive by substracting the minimum value.

# %%
kruskal_rank = 3

# %%
regular_3_rand = parafac(sonar_tensor-sonar_tensor.min(),  # regular kruskal
                       rank = 3,
                       n_iter_max=50000, 
                       verbose=1, 
                       tol=1e-10,
                       init='svd',
                       normalize_factors=True)
# Out:
# reconstruction error=0.06980115331418808
# reconstruction error=0.0621605914631619, variation=0.007640561851026184.
# reconstruction error=0.058166793428016624, variation=0.003993798035145275.
# reconstruction error=0.056471945607341104, variation=0.00169484782067552.
# reconstruction error=0.05561299950801092, variation=0.0008589460993301823.
# reconstruction error=0.05511315601075868, variation=0.0004998434972522392.
# reconstruction error=0.054798764150708945, variation=0.00031439186004973696.
# reconstruction error=0.05458973841452421, variation=0.0002090257361847328.
# reconstruction error=0.054444366855686266, variation=0.00014537155883794645.
# reconstruction error=0.05433936568476806, variation=0.0001050011709182036.
# reconstruction error=0.05426103144375074, variation=7.83342410173235e-05.
# reconstruction error=0.05420093371409086, variation=6.00977296598762e-05.
# reconstruction error=0.054153687464734764, variation=4.724624935609906e-05.
# reconstruction error=0.05411574056078654, variation=3.794690394822581e-05.
# reconstruction error=0.05408468357516422, variation=3.105698562231446e-05.
# reconstruction error=0.054058841330424975, variation=2.5842244739247844e-05.
# reconstruction error=0.05403702292740544, variation=2.181840301953425e-05.
# reconstruction error=0.05401836427884508, variation=1.8658648560362923e-05.
# reconstruction error=0.05400222639843118, variation=1.6137880413900907e-05.
# reconstruction error=0.05398812825118324, variation=1.4098147247940118e-05.
# reconstruction error=0.05397570155718745, variation=1.242669399578733e-05.
# reconstruction error=0.05396465984166779, variation=1.1041715519660711e-05.
# reconstruction error=0.05395477690631175, variation=9.882935356038403e-06.
# reconstruction error=0.053945871635005305, variation=8.905271306446083e-06.
# reconstruction error=0.05393779712204879, variation=8.074512956514346e-06.
# reconstruction error=0.05393043279086807, variation=7.364331180717554e-06.
# reconstruction error=0.05392367860641738, variation=6.754184450695477e-06.
# reconstruction error=0.05391745077091368, variation=6.227835503698487e-06.
# reconstruction error=0.0539116784823566, variation=5.772288557082117e-06.
# reconstruction error=0.05390630146276072, variation=5.377019595874388e-06.
# reconstruction error=0.053901268049651736, variation=5.033413108986029e-06.
# reconstruction error=0.05389653370465013, variation=4.734345001602969e-06.
# reconstruction error=0.05389205983429372, variation=4.473870356416776e-06.
# reconstruction error=0.053887812846879685, variation=4.2469874140319e-06.
# reconstruction error=0.05388376339008016, variation=4.049456799527784e-06.
# reconstruction error=0.053879885728828444, variation=3.877661251712461e-06.
# reconstruction error=0.05387615723227974, variation=3.7284965487063837e-06.
# reconstruction error=0.053872557947795455, variation=3.599284484283316e-06.
# reconstruction error=0.0538690702443533, variation=3.4877034421551545e-06.
# reconstruction error=0.05386567851154265, variation=3.3917328106508604e-06.
# reconstruction error=0.053862368904492815, variation=3.3096070498339625e-06.
# reconstruction error=0.053859129126221775, variation=3.2397782710399947e-06.
# reconstruction error=0.053855948241090267, variation=3.1808851315082154e-06.
# reconstruction error=0.05385281651390506, variation=3.1317271852043804e-06.
# reconstruction error=0.053849725270907665, variation=3.091242997396715e-06.
# reconstruction error=0.053846666779261886, variation=3.0584916457798705e-06.
# reconstruction error=0.05384363414166756, variation=3.0326375943245942e-06.
# reconstruction error=0.053840621204491464, variation=3.0129371760972967e-06.
# reconstruction error=0.0538376224771612, variation=2.998727330262574e-06.
# reconstruction error=0.05383463306109877, variation=2.9894160624294175e-06.
# reconstruction error=0.05383164858736586, variation=2.9844737329115523e-06.
# reconstruction error=0.053828665160993557, variation=2.983426372303588e-06.
# reconstruction error=0.05382567931224565, variation=2.9858487479092477e-06.
# reconstruction error=0.05382268795271215, variation=2.9913595334940535e-06.
# reconstruction error=0.05381968833665641, variation=2.9996160557446694e-06.
# reconstruction error=0.05381667802606186, variation=3.010310594547816e-06.
# reconstruction error=0.053813654859972124, variation=3.023166089737017e-06.
# reconstruction error=0.0538106169263357, variation=3.0379336364225185e-06.
# reconstruction error=0.05380756253733963, variation=3.054388996073798e-06.
# reconstruction error=0.053804490206924245, variation=3.0723304153823516e-06.
# reconstruction error=0.05380139863060375, variation=3.091576320495004e-06.
# reconstruction error=0.05379828666755082, variation=3.1119630529291564e-06.
# reconstruction error=0.053795153324408304, variation=3.133343142516787e-06.
# reconstruction error=0.05379199774045298, variation=3.15558395532628e-06.
# reconstruction error=0.05378881917474191, variation=3.1785657110677823e-06.
# reconstruction error=0.05378561699424306, variation=3.202180498852736e-06.
# reconstruction error=0.05378239066339143, variation=3.2263308516258804e-06.
# reconstruction error=0.053779139734722675, variation=3.250928668756259e-06.
# reconstruction error=0.05377586384049418, variation=3.2758942284938364e-06.
# reconstruction error=0.05377256268524252, variation=3.301155251662913e-06.
# reconstruction error=0.05376923603935176, variation=3.3266458907554863e-06.
# reconstruction error=0.05376588373308811, variation=3.352306263651461e-06.
# reconstruction error=0.053762505651738395, variation=3.378081349716955e-06.
# reconstruction error=0.053759101731066836, variation=3.403920671558869e-06.
# reconstruction error=0.05375567195355637, variation=3.429777510464971e-06.
# reconstruction error=0.05375221634514441, variation=3.4556084119591324e-06.
# reconstruction error=0.0537487349724328, variation=3.481372711611197e-06.
# reconstruction error=0.05374522794031822, variation=3.507032114581643e-06.
# reconstruction error=0.053741695390099514, variation=3.5325502187044666e-06.
# reconstruction error=0.05373813749766559, variation=3.557892433926624e-06.
# reconstruction error=0.05373455447232938, variation=3.583025336206802e-06.
# reconstruction error=0.05373094655577427, variation=3.6079165551122783e-06.
# reconstruction error=0.05372731402126615, variation=3.632534508121732e-06.
# reconstruction error=0.053723657172779764, variation=3.6568484863830353e-06.
# reconstruction error=0.053719976344884283, variation=3.6808278954802987e-06.
# reconstruction error=0.05371627190199803, variation=3.7044428862556544e-06.
# reconstruction error=0.053712544238427314, variation=3.727663570714246e-06.
# reconstruction error=0.05370879377812838, variation=3.750460298934666e-06.
# reconstruction error=0.05370502097446019, variation=3.772803668186664e-06.
# reconstruction error=0.05370122631027332, variation=3.7946641868735753e-06.
# reconstruction error=0.0536974102977013, variation=3.8160125720165805e-06.
# reconstruction error=0.053693573478062646, variation=3.836819638655675e-06.
# reconstruction error=0.053689716421895815, variation=3.857056166831074e-06.
# reconstruction error=0.05368583972859531, variation=3.876693300507161e-06.
# reconstruction error=0.05368194402655055, variation=3.895702044759419e-06.
# reconstruction error=0.05367802997243921, variation=3.914054111341103e-06.
# reconstruction error=0.053674098251381794, variation=3.931721057413851e-06.
# reconstruction error=0.05367014957630709, variation=3.948675074701147e-06.
# reconstruction error=0.053666184687635204, variation=3.9648886718882115e-06.
# reconstruction error=0.053662204352538864, variation=3.980335096340215e-06.
# reconstruction error=0.0536582093647705, variation=3.99498776836732e-06.
# reconstruction error=0.05365420054345155, variation=4.00882131895014e-06.
# reconstruction error=0.053650178732786186, variation=4.021810665361114e-06.
# reconstruction error=0.05364614480099421, variation=4.033931791977419e-06.
# reconstruction error=0.05364209963937879, variation=4.045161615416626e-06.
# reconstruction error=0.05363804416154043, variation=4.055477838361965e-06.
# reconstruction error=0.0536339793020984, variation=4.0648594420295e-06.
# reconstruction error=0.05362990601584723, variation=4.073286251168873e-06.
# reconstruction error=0.053625825276258, variation=4.080739589233662e-06.
# reconstruction error=0.05362173807456806, variation=4.087201689935427e-06.
# reconstruction error=0.05361764541838704, variation=4.092656181023391e-06.
# reconstruction error=0.05361354833020948, variation=4.097088177557051e-06.
# reconstruction error=0.05360944784633534, variation=4.10048387414208e-06.
# reconstruction error=0.05360534501531335, variation=4.10283102198622e-06.
# reconstruction error=0.05360124089647374, variation=4.104118839616533e-06.
# reconstruction error=0.05359713655852343, variation=4.10433795030446e-06.
# reconstruction error=0.053593033078192215, variation=4.103480331217602e-06.
# reconstruction error=0.05358893153851222, variation=4.101539679994548e-06.
# reconstruction error=0.05358483302754146, variation=4.09851097075975e-06.
# reconstruction error=0.053580738636609684, variation=4.0943909317761595e-06.
# reconstruction error=0.05357664945917573, variation=4.0891774339552045e-06.
# reconstruction error=0.053572566588938296, variation=4.0828702374332004e-06.
# reconstruction error=0.053568491118571676, variation=4.075470366619871e-06.
# reconstruction error=0.053564424138203, variation=4.066980368679085e-06.
# reconstruction error=0.05356036673404224, variation=4.057404160755229e-06.
# reconstruction error=0.05355631998670636, variation=4.0467473358812844e-06.
# reconstruction error=0.05355228496999896, variation=4.035016707398809e-06.
# reconstruction error=0.05354826274941347, variation=4.022220585493674e-06.
# reconstruction error=0.053544254380915736, variation=4.008368497732118e-06.
# reconstruction error=0.053540260909477305, variation=3.993471438430707e-06.
# reconstruction error=0.05353628336777509, variation=3.977541702213094e-06.
# reconstruction error=0.05353232277501017, variation=3.96059276492472e-06.
# reconstruction error=0.05352838013566496, variation=3.942639345208554e-06.
# reconstruction error=0.0535244564383681, variation=3.923697296862039e-06.
# reconstruction error=0.05352055265463905, variation=3.903783729046484e-06.
# reconstruction error=0.05351666973791918, variation=3.882916719870344e-06.
# reconstruction error=0.053512808622543526, variation=3.8611153756543115e-06.
# reconstruction error=0.05350897022262626, variation=3.838399917265034e-06.
# reconstruction error=0.053505155431298336, variation=3.814791327924616e-06.
# reconstruction error=0.05350136511964858, variation=3.790311649758127e-06.
# reconstruction error=0.053497600136010424, variation=3.7649836381534185e-06.
# reconstruction error=0.05349386130508775, variation=3.7388309226740746e-06.
# reconstruction error=0.05349014942728174, variation=3.7118778060118984e-06.
# reconstruction error=0.05348646527795651, variation=3.684149325229591e-06.
# reconstruction error=0.05348280960690124, variation=3.6556710552720917e-06.
# reconstruction error=0.053479183137753884, variation=3.62646914735254e-06.
# reconstruction error=0.05347558656735903, variation=3.596570394850951e-06.
# reconstruction error=0.05347202056546288, variation=3.566001896153359e-06.
# reconstruction error=0.053468485774265655, variation=3.5347911972252732e-06.
# reconstruction error=0.053464982807919684, variation=3.5029663459709703e-06.
# reconstruction error=0.053461512252521035, variation=3.4705553986491555e-06.
# reconstruction error=0.05345807466568464, variation=3.4375868363939466e-06.
# reconstruction error=0.05345467057633692, variation=3.4040893477221834e-06.
# reconstruction error=0.05345130048463079, variation=3.3700917061313396e-06.
# reconstruction error=0.05344796486184047, variation=3.335622790319459e-06.
# reconstruction error=0.053444664150449024, variation=3.3007113914435005e-06.
# reconstruction error=0.05344139876393494, variation=3.265386514086921e-06.
# reconstruction error=0.05343816908700959, variation=3.229676925349534e-06.
# reconstruction error=0.0534349754756444, variation=3.1936113651861997e-06.
# reconstruction error=0.053431818257266006, variation=3.1572183783953878e-06.
# reconstruction error=0.05342869773094931, variation=3.1205263166939057e-06.
# reconstruction error=0.05342561416763829, variation=3.0835633110237737e-06.
# reconstruction error=0.05342256781044169, variation=3.0463571965982927e-06.
# reconstruction error=0.05341955887490896, variation=3.0089355327334033e-06.
# reconstruction error=0.05341658754951029, variation=2.9713253986637933e-06.
# reconstruction error=0.05341365399590419, variation=2.933553606102035e-06.
# reconstruction error=0.05341075834936633, variation=2.89564653786073e-06.
# reconstruction error=0.05340790071938424, variation=2.8576299820892714e-06.
# reconstruction error=0.053405081189998586, variation=2.8195293856544956e-06.
# reconstruction error=0.05340229982031487, variation=2.7813696837145074e-06.
# reconstruction error=0.0533995566452491, variation=2.743175065773873e-06.
# reconstruction error=0.053396851675838526, variation=2.704969410571856e-06.
# reconstruction error=0.05339418489998824, variation=2.6667758502851857e-06.
# reconstruction error=0.05339155628300038, variation=2.6286169878611543e-06.
# reconstruction error=0.05338896576828528, variation=2.5905147151006336e-06.
# reconstruction error=0.053386413277907434, variation=2.5524903778453845e-06.
# reconstruction error=0.05338389871324537, variation=2.5145646620622353e-06.
# reconstruction error=0.05338142195583089, variation=2.4767574144796134e-06.
# reconstruction error=0.05337898286775349, variation=2.439088077399454e-06.
# reconstruction error=0.05337658129256172, variation=2.4015751917752515e-06.
# reconstruction error=0.05337421705588371, variation=2.36423667800828e-06.
# reconstruction error=0.05337188996613661, variation=2.3270897471019958e-06.
# reconstruction error=0.05336959981515689, variation=2.290150979716854e-06.
# reconstruction error=0.053367346379037464, variation=2.2534361194259667e-06.
# reconstruction error=0.053365129418686146, variation=2.216960351318631e-06.
# reconstruction error=0.0533629486806725, variation=2.180738013647654e-06.
# reconstruction error=0.05336080389772109, variation=2.144782951407631e-06.
# reconstruction error=0.05335869478975641, variation=2.1091079646790023e-06.
# reconstruction error=0.0533566210641562, variation=2.07372560021013e-06.
# reconstruction error=0.05335458241669706, variation=2.0386474591377324e-06.
# reconstruction error=0.053352578532259845, variation=2.0038844372183284e-06.
# reconstruction error=0.053350609085337904, variation=1.969446921941398e-06.
# reconstruction error=0.05334867374080415, variation=1.9353445337502717e-06.
# reconstruction error=0.05334677215447652, variation=1.9015863276308775e-06.
# reconstruction error=0.05334490397384012, variation=1.86818063640376e-06.
# reconstruction error=0.05334306883856533, variation=1.8351352747900118e-06.
# reconstruction error=0.05334126638120318, variation=1.8024573621502893e-06.
# reconstruction error=0.05333949622769927, variation=1.7701535039091332e-06.
# reconstruction error=0.05333775799808258, variation=1.738229616687903e-06.
# reconstruction error=0.05333605130687079, variation=1.7066912117932875e-06.
# reconstruction error=0.05333437576374352, variation=1.6755431272649779e-06.
# reconstruction error=0.053332730974045464, variation=1.6447896980589793e-06.
# reconstruction error=0.05333111653931001, variation=1.6144347354529742e-06.
# reconstruction error=0.05332953205769686, variation=1.5844816131510564e-06.
# reconstruction error=0.053327977124472646, variation=1.5549332242140168e-06.
# reconstruction error=0.053326451332641626, variation=1.5257918310196406e-06.
# reconstruction error=0.05332495427326085, variation=1.4970593807742127e-06.
# reconstruction error=0.053323485535703194, variation=1.4687375576583062e-06.
# reconstruction error=0.05332204470850832, variation=1.440827194873484e-06.
# reconstruction error=0.053320631379409754, variation=1.4133290985665625e-06.
# reconstruction error=0.05331924513578417, variation=1.3862436255840382e-06.
# reconstruction error=0.05331788556522336, variation=1.3595705608132613e-06.
# reconstruction error=0.053316552255586167, variation=1.3333096371900832e-06.
# reconstruction error=0.05331524479549344, variation=1.3074600927268087e-06.
# reconstruction error=0.05331396277476596, variation=1.282020727480515e-06.
# reconstruction error=0.05331270578446066, variation=1.256990305301131e-06.
# reconstruction error=0.05331147341725647, variation=1.2323672041875122e-06.
# reconstruction error=0.05331026526791506, variation=1.2081493414098365e-06.
# reconstruction error=0.05330908093320805, variation=1.1843347070134014e-06.
# reconstruction error=0.05330792001242083, variation=1.1609207872173566e-06.
# reconstruction error=0.05330678210747051, variation=1.137904950321289e-06.
# reconstruction error=0.05330566682310547, variation=1.1152843650413802e-06.
# reconstruction error=0.05330457376720938, variation=1.0930558960869918e-06.
# reconstruction error=0.05330350255074416, variation=1.0712164652190714e-06.
# reconstruction error=0.05330245278830833, variation=1.0497624358327129e-06.
# reconstruction error=0.053301424097934466, variation=1.0286903738623843e-06.
# reconstruction error=0.053300416101406824, variation=1.0079965276424407e-06.
# reconstruction error=0.0532994284244267, variation=9.876769801256402e-07.
# reconstruction error=0.05329846069666643, variation=9.677277602662682e-07.
# reconstruction error=0.0532975125519075, variation=9.481447589346215e-07.
# reconstruction error=0.053296583628103564, variation=9.289238039333902e-07.
# reconstruction error=0.05329567356765468, variation=9.100604488818109e-07.
# reconstruction error=0.053294782017195515, variation=8.91550459167223e-07.
# reconstruction error=0.05329390862797623, variation=8.733892192872017e-07.
# reconstruction error=0.05329305305569825, variation=8.555722779760022e-07.
# reconstruction error=0.053292214960658946, variation=8.380950393058195e-07.
# reconstruction error=0.05329139400790072, variation=8.209527582250797e-07.
# reconstruction error=0.05329058986709663, variation=8.041408040906917e-07.
# reconstruction error=0.05328980221263135, variation=7.876544652826722e-07.
# reconstruction error=0.05328903072375918, variation=7.714888721685464e-07.
# reconstruction error=0.05328827508444199, variation=7.556393171875841e-07.
# reconstruction error=0.05328753498345711, variation=7.40100984879255e-07.
# reconstruction error=0.05328681011431693, variation=7.248691401839924e-07.
# reconstruction error=0.053286100175535846, variation=7.099387810821645e-07.
# reconstruction error=0.053285404870327055, variation=6.953052087907419e-07.
# reconstruction error=0.053284723906703635, variation=6.809636234200722e-07.
# reconstruction error=0.05328405699757739, variation=6.669091262428983e-07.
# reconstruction error=0.05328340386048043, variation=6.531370969620198e-07.
# reconstruction error=0.05328276421795925, variation=6.396425211788181e-07.
# reconstruction error=0.05328213779711229, variation=6.264208469580756e-07.
# reconstruction error=0.053281524329768126, variation=6.134673441668403e-07.
# reconstruction error=0.05328092355261355, variation=6.007771545732399e-07.
# reconstruction error=0.05328033520678566, variation=5.883458278899134e-07.
# reconstruction error=0.053279759038188386, variation=5.761685972771602e-07.
# reconstruction error=0.053279194797268524, variation=5.64240919861958e-07.
# reconstruction error=0.05327864223902556, variation=5.525582429666276e-07.
# reconstruction error=0.053278101122889804, variation=5.411161357535277e-07.
# reconstruction error=0.05327757121284809, variation=5.299100417147096e-07.
# reconstruction error=0.053277052277310465, variation=5.189355376244986e-07.
# reconstruction error=0.0532765440888791, variation=5.081884313640206e-07.
# reconstruction error=0.05327604642463983, variation=4.976642392698349e-07.
# reconstruction error=0.05327555906585605, variation=4.873587837808668e-07.
# reconstruction error=0.05327508179804662, variation=4.772678094330796e-07.
# reconstruction error=0.053274614410845536, variation=4.6738720108074894e-07.
# reconstruction error=0.053274156697943484, variation=4.577129020522097e-07.
# reconstruction error=0.05327370845712927, variation=4.4824081421590556e-07.
# reconstruction error=0.05327326949011312, variation=4.389670161461523e-07.
# reconstruction error=0.05327283960260903, variation=4.298875040942285e-07.
# reconstruction error=0.053272418604189756, variation=4.209984192718452e-07.
# reconstruction error=0.05327200630810333, variation=4.1229608642445736e-07.
# reconstruction error=0.05327160253150298, variation=4.037766003495147e-07.
# reconstruction error=0.05327120709514759, variation=3.954363553895779e-07.
# reconstruction error=0.053270819823456696, variation=3.872716908964735e-07.
# reconstruction error=0.05327044054440409, variation=3.792790526091494e-07.
# reconstruction error=0.05327006908949092, variation=3.714549131686451e-07.
# reconstruction error=0.05326970529364609, variation=3.63795844830761e-07.
# reconstruction error=0.053269348995172085, variation=3.5629847400242554e-07.
# reconstruction error=0.05326900003579757, variation=3.4895937451456804e-07.
# reconstruction error=0.053268658260407324, variation=3.417753902459908e-07.
# reconstruction error=0.0532683235172084, variation=3.3474319892368154e-07.
# reconstruction error=0.05326799565752596, variation=3.2785968243770336e-07.
# reconstruction error=0.05326767453568992, variation=3.2112183604576794e-07.
# reconstruction error=0.05326736000926244, variation=3.1452642747925585e-07.
# reconstruction error=0.05326705193864058, variation=3.0807062186000156e-07.
# reconstruction error=0.053266750187272414, variation=3.017513681632944e-07.
# reconstruction error=0.05326645462137545, variation=2.95565896965555e-07.
# reconstruction error=0.05326616510999372, variation=2.8951138172916835e-07.
# reconstruction error=0.05326588152505255, variation=2.835849411686464e-07.
# reconstruction error=0.05326560374108604, variation=2.777839665096815e-07.
# reconstruction error=0.05326533163532138, variation=2.7210576466346614e-07.
# reconstruction error=0.05326506508758816, variation=2.665477332186583e-07.
# reconstruction error=0.05326480398030942, variation=2.611072787359059e-07.
# reconstruction error=0.053264548198336, variation=2.5578197342113196e-07.
# reconstruction error=0.053264297629008035, variation=2.505693279669652e-07.
# reconstruction error=0.0532640521621551, variation=2.4546685293419523e-07.
# reconstruction error=0.0532638116898783, variation=2.4047227679957484e-07.
# reconstruction error=0.05326357610659347, variation=2.3558328483136437e-07.
# reconstruction error=0.053263345308981434, variation=2.3079761203581572e-07.
# reconstruction error=0.05326311919600854, variation=2.2611297289393262e-07.
# reconstruction error=0.05326289766865864, variation=2.215273499014958e-07.
# reconstruction error=0.05326268063018097, variation=2.1703847766924023e-07.
# reconstruction error=0.053262467985912956, variation=2.1264426801337333e-07.
# reconstruction error=0.053262259643119, variation=2.0834279395448574e-07.
# reconstruction error=0.05326205551116558, variation=2.041319534240582e-07.
# reconstruction error=0.0532618555012373, variation=2.0000992827923225e-07.
# reconstruction error=0.05326165952661877, variation=1.959746185262179e-07.
# reconstruction error=0.05326146750235386, variation=1.920242649125492e-07.
# reconstruction error=0.053261279345293434, variation=1.8815706042535352e-07.
# reconstruction error=0.05326109497411825, variation=1.8437117518116386e-07.
# reconstruction error=0.053260914309302666, variation=1.8066481558692837e-07.
# reconstruction error=0.05326073727302605, variation=1.77036276617637e-07.
# reconstruction error=0.05326056378902971, variation=1.7348399633521083e-07.
# reconstruction error=0.053260393782894266, variation=1.700061354470428e-07.
# reconstruction error=0.05326022718166466, variation=1.6660122960365786e-07.
# reconstruction error=0.053260063914038945, variation=1.6326762571766684e-07.
# reconstruction error=0.05325990391017054, variation=1.6000386840464564e-07.
# reconstruction error=0.053259747101866095, variation=1.568083044453661e-07.
# reconstruction error=0.053259593422160516, variation=1.5367970557927935e-07.
# reconstruction error=0.05325944280580563, variation=1.506163548881112e-07.
# reconstruction error=0.05325929518885671, variation=1.476169489145196e-07.
# reconstruction error=0.053259150508708754, variation=1.446801479593196e-07.
# reconstruction error=0.053259008704096646, variation=1.418046121082206e-07.
# reconstruction error=0.05325886971517469, variation=1.3898892195496337e-07.
# reconstruction error=0.05325873348329625, variation=1.3623187843786466e-07.
# reconstruction error=0.053258599951141024, variation=1.335321552289881e-07.
# reconstruction error=0.0532584690625469, variation=1.308885941228577e-07.
# reconstruction error=0.05325834076270097, variation=1.2829984592788168e-07.
# reconstruction error=0.05325821499782361, variation=1.2576487736642994e-07.
# reconstruction error=0.05325809171536167, variation=1.232824619334938e-07.
# reconstruction error=0.05325797086393179, variation=1.208514298842167e-07.
# reconstruction error=0.053257852393113495, variation=1.1847081829441386e-07.
# reconstruction error=0.05325773625378798, variation=1.1613932551779449e-07.
# reconstruction error=0.0532576223976994, variation=1.1385608857800156e-07.
# reconstruction error=0.053257510777723165, variation=1.116199762341008e-07.
# reconstruction error=0.053257401347745474, variation=1.0942997769047835e-07.
# reconstruction error=0.05325729406262926, variation=1.072851162145505e-07.
# reconstruction error=0.05325718887814602, variation=1.0518448324142726e-07.
# reconstruction error=0.053257085751148577, variation=1.0312699744163822e-07.
# reconstruction error=0.05325698463931432, variation=1.0111183425948189e-07.
# reconstruction error=0.05325688550119969, variation=9.913811462730626e-08.
# reconstruction error=0.05325678829640849, variation=9.720479120234327e-08.
# reconstruction error=0.05325669298520089, variation=9.531120759992406e-08.
# reconstruction error=0.0532565995288276, variation=9.345637328600498e-08.
# reconstruction error=0.05325650788936401, variation=9.163946359386221e-08.
# reconstruction error=0.05325641802960556, variation=8.985975844671978e-08.
# reconstruction error=0.05325632991320193, variation=8.811640363204365e-08.
# reconstruction error=0.053256243504629784, variation=8.640857214470277e-08.
# reconstruction error=0.05325615876901547, variation=8.47356143168776e-08.
# reconstruction error=0.05325607567232369, variation=8.309669177752887e-08.
# reconstruction error=0.053255994181146155, variation=8.149117753514235e-08.
# reconstruction error=0.05325591426285385, variation=7.991829230336034e-08.
# reconstruction error=0.05325583588553805, variation=7.837731580417895e-08.
# reconstruction error=0.053255759017878344, variation=7.686765970266185e-08.
# reconstruction error=0.053255683629315514, variation=7.538856282990336e-08.
# reconstruction error=0.053255609689840146, variation=7.393947536876722e-08.
# reconstruction error=0.05325553717018124, variation=7.251965890298084e-08.
# reconstruction error=0.05325546604157902, variation=7.112860222341366e-08.
# reconstruction error=0.053255396275993946, variation=6.976558507287844e-08.
# reconstruction error=0.053255327845897704, variation=6.843009624224461e-08.
# reconstruction error=0.05325526072440045, variation=6.712149725612848e-08.
# reconstruction error=0.05325519488513039, variation=6.58392700567112e-08.
# reconstruction error=0.05325513030226328, variation=6.458286710975258e-08.
# reconstruction error=0.05325506695063618, variation=6.335162710396913e-08.
# reconstruction error=0.05325500480542003, variation=6.214521614672508e-08.
# reconstruction error=0.05325494384251755, variation=6.0962902483086e-08.
# reconstruction error=0.05325488403817447, variation=5.980434307495397e-08.
# reconstruction error=0.05325482536922737, variation=5.866894710326864e-08.
# reconstruction error=0.053254767812958174, variation=5.75562691951248e-08.
# reconstruction error=0.05325471134716462, variation=5.6465793554782984e-08.
# reconstruction error=0.05325465595009888, variation=5.5397065740203644e-08.
# reconstruction error=0.053254601600381285, variation=5.434971759449292e-08.
# reconstruction error=0.053254548277209296, variation=5.332317198902814e-08.
# reconstruction error=0.053254495960159916, variation=5.231704938019055e-08.
# reconstruction error=0.053254444629237306, variation=5.1330922609671426e-08.
# reconstruction error=0.05325439426482737, variation=5.036440993422264e-08.
# reconstruction error=0.05325434484776374, variation=4.9417063628653946e-08.
# reconstruction error=0.05325429635930268, variation=4.848846106575433e-08.
# reconstruction error=0.05325424878106858, variation=4.757823409556883e-08.
# reconstruction error=0.05325420209501534, variation=4.66860532385982e-08.
# reconstruction error=0.0532541562836082, variation=4.58114071399951e-08.
# reconstruction error=0.053254111329455504, variation=4.4954152698950534e-08.
# reconstruction error=0.05325406721576785, variation=4.411368765416812e-08.
# reconstruction error=0.053254023925953534, variation=4.328981431656054e-08.
# reconstruction error=0.053253981443825336, variation=4.248212819718544e-08.
# reconstruction error=0.05325393975346423, variation=4.169036110779345e-08.
# reconstruction error=0.05325389883938067, variation=4.0914083558607484e-08.
# reconstruction error=0.05325385868629875, variation=4.0153081921900924e-08.
# reconstruction error=0.053253819279340246, variation=3.940695850190856e-08.
# reconstruction error=0.05325378060388601, variation=3.8675454235026496e-08.
# reconstruction error=0.05325374264563963, variation=3.795824637942147e-08.
# reconstruction error=0.05325370539062509, variation=3.725501453860636e-08.
# reconstruction error=0.053253668825080015, variation=3.656554507791565e-08.
# reconstruction error=0.053253632935592016, variation=3.5889487999540837e-08.
# reconstruction error=0.05325359770895551, variation=3.5226636503626896e-08.
# reconstruction error=0.05325356313234672, variation=3.4576608791414554e-08.
# reconstruction error=0.05325352919309414, variation=3.3939252581938195e-08.
# reconstruction error=0.05325349587883078, variation=3.331426336183885e-08.
# reconstruction error=0.053253463177451034, variation=3.270137974298315e-08.
# reconstruction error=0.05325343107709246, variation=3.210035857265092e-08.
# reconstruction error=0.05325339956603124, variation=3.151106121868086e-08.
# reconstruction error=0.053253368633034495, variation=3.093299674739036e-08.
# reconstruction error=0.05325333826682383, variation=3.0366210664045656e-08.
# reconstruction error=0.05325330845646863, variation=2.981035519822317e-08.
# reconstruction error=0.053253279191365556, variation=2.9265103076991927e-08.
# reconstruction error=0.05325325046089986, variation=2.8730465694015717e-08.
# reconstruction error=0.053253222254868185, variation=2.8206031676969445e-08.
# reconstruction error=0.05325319456314672, variation=2.769172146449561e-08.
# reconstruction error=0.05325316737588665, variation=2.7187260068228802e-08.
# reconstruction error=0.053253140683446026, variation=2.6692440625863956e-08.
# reconstruction error=0.05325311447630782, variation=2.6207138209555225e-08.
# reconstruction error=0.053253088745173253, variation=2.5731134563333757e-08.
# reconstruction error=0.053253063481057177, variation=2.526411607695067e-08.
# reconstruction error=0.05325303867490853, variation=2.4806148649081372e-08.
# reconstruction error=0.05325301431806488, variation=2.435684364615609e-08.
# reconstruction error=0.053252990401961575, variation=2.3916103306098613e-08.
# reconstruction error=0.053252966918206655, variation=2.3483754919839672e-08.
# reconstruction error=0.05325294385857637, variation=2.3059630288591038e-08.
# reconstruction error=0.0532529212150333, variation=2.264354306835692e-08.
# reconstruction error=0.05325289897969466, variation=2.2235338639764457e-08.
# reconstruction error=0.05325287714478669, variation=2.1834907971973738e-08.
# reconstruction error=0.053252855702740194, variation=2.1442046492514688e-08.
# reconstruction error=0.05325283464613604, variation=2.105660415474553e-08.
# reconstruction error=0.053252813967684574, variation=2.0678451465028225e-08.
# reconstruction error=0.05325279366027803, variation=2.0307406541075768e-08.
# reconstruction error=0.053252773716883625, variation=1.9943394408139525e-08.
# reconstruction error=0.053252754130670855, variation=1.9586212769706624e-08.
# reconstruction error=0.05325273489489332, variation=1.923577753332184e-08.
# reconstruction error=0.05325271600302964, variation=1.889186368453366e-08.
# reconstruction error=0.053252697448515254, variation=1.8554514383262166e-08.
# reconstruction error=0.05325267922510379, variation=1.8223411467344075e-08.
# reconstruction error=0.053252661326592086, variation=1.7898511700531472e-08.
# reconstruction error=0.05325264374687241, variation=1.757971967303318e-08.
# reconstruction error=0.0532526264799939, variation=1.7266878510335815e-08.
# reconstruction error=0.05325260952008976, variation=1.695990414080084e-08.
# reconstruction error=0.05325259286149096, variation=1.6658598799013102e-08.
# reconstruction error=0.05325257649845117, variation=1.6363039791189582e-08.
# reconstruction error=0.05325256042565141, variation=1.6072799764732526e-08.
# reconstruction error=0.053252544637554446, variation=1.5788096961733e-08.
# reconstruction error=0.053252529128957206, variation=1.5508597239755062e-08.
# reconstruction error=0.05325251389460433, variation=1.5234352876425383e-08.
# reconstruction error=0.05325249892941319, variation=1.4965191141858014e-08.
# reconstruction error=0.053252484228458026, variation=1.4700955161539575e-08.
# reconstruction error=0.05325246978677666, variation=1.4441681364663062e-08.
# reconstruction error=0.053252455599581985, variation=1.4187194675996384e-08.
# reconstruction error=0.05325244166224824, variation=1.3937333745439595e-08.
# reconstruction error=0.053252427970097396, variation=1.3692150843680473e-08.
# reconstruction error=0.05325241451862873, variation=1.3451468668101985e-08.
# reconstruction error=0.05325240130341423, variation=1.3215214499096017e-08.
# reconstruction error=0.053252388320046355, variation=1.2983367873864449e-08.
# reconstruction error=0.05325237556436986, variation=1.2755676494224932e-08.
# reconstruction error=0.05325236303216134, variation=1.2532208520932286e-08.
# reconstruction error=0.05325235071927462, variation=1.2312886717158467e-08.
# reconstruction error=0.05325233862174313, variation=1.2097531490451452e-08.
# reconstruction error=0.05325232673558666, variation=1.1886156475737764e-08.
# reconstruction error=0.053252315057006824, variation=1.1678579832363756e-08.
# reconstruction error=0.05325230358214615, variation=1.1474860672766596e-08.
# reconstruction error=0.053252292307317636, variation=1.1274828515261959e-08.
# reconstruction error=0.0532522812288161, variation=1.1078501539751873e-08.
# reconstruction error=0.053252270343159124, variation=1.0885656973047553e-08.
# reconstruction error=0.05325225964677107, variation=1.0696388053066386e-08.
# reconstruction error=0.05325224913619681, variation=1.0510574258160155e-08.
# reconstruction error=0.05325223880811529, variation=1.0328081521959742e-08.
# reconstruction error=0.053252228659203205, variation=1.014891208572788e-08.
# reconstruction error=0.053252218686203154, variation=9.97300005078916e-09.
# reconstruction error=0.05325220888593731, variation=9.800265841908296e-09.
# reconstruction error=0.05325219925525056, variation=9.630686755024431e-09.
# reconstruction error=0.05325218979105597, variation=9.464194587749386e-09.
# reconstruction error=0.0532521804904235, variation=9.300632472508674e-09.
# reconstruction error=0.05325217135035939, variation=9.140064108348334e-09.
# reconstruction error=0.053252162367963145, variation=8.98239624347319e-09.
# reconstruction error=0.05325215354042515, variation=8.827537992250889e-09.
# reconstruction error=0.05325214486492444, variation=8.675500713650752e-09.
# reconstruction error=0.05325213633875597, variation=8.526168465694539e-09.
# reconstruction error=0.05325212795923517, variation=8.379520806400809e-09.
# reconstruction error=0.05325211972367288, variation=8.235562287683962e-09.
# reconstruction error=0.05325211162957094, variation=8.094101937305975e-09.
# reconstruction error=0.05325210367434705, variation=7.955223889355434e-09.
# reconstruction error=0.053252095855530285, variation=7.818816767646286e-09.
# reconstruction error=0.053252088170699735, variation=7.684830549692379e-09.
# reconstruction error=0.05325208061744815, variation=7.553251586689402e-09.
# reconstruction error=0.053252073193384146, variation=7.424064002448105e-09.
# reconstruction error=0.05325206589626188, variation=7.297122267546641e-09.
# reconstruction error=0.053252058723789984, variation=7.1724718941901244e-09.
# reconstruction error=0.053252051673804424, variation=7.0499855606143136e-09.
# reconstruction error=0.053252044744027484, variation=6.929776939779142e-09.
# reconstruction error=0.05325203793242016, variation=6.811607326795421e-09.
# reconstruction error=0.05325203123684794, variation=6.695572214721057e-09.
# reconstruction error=0.05325202465524225, variation=6.5816056910028564e-09.
# reconstruction error=0.053252018185600436, variation=6.46964181533205e-09.
# reconstruction error=0.05325201182592667, variation=6.359673766775931e-09.
# reconstruction error=0.05325200557424782, variation=6.2516788482125385e-09.
# reconstruction error=0.05325199942870673, variation=6.1455410899080576e-09.
# reconstruction error=0.05325199338744394, variation=6.04126278863637e-09.
# reconstruction error=0.05325198744860455, variation=5.938839392483075e-09.
# reconstruction error=0.05325198161030183, variation=5.838302723215616e-09.
# reconstruction error=0.05325197587089455, variation=5.739407275828778e-09.
# reconstruction error=0.053251970228555094, variation=5.642339456768397e-09.
# reconstruction error=0.05325196468159902, variation=5.546956075019871e-09.
# reconstruction error=0.05325195922833964, variation=5.453259378784825e-09.
# reconstruction error=0.053251953867163006, variation=5.361176634577358e-09.
# reconstruction error=0.053251948596450625, variation=5.270712380434084e-09.
# reconstruction error=0.05325194341462263, variation=5.181827994471533e-09.
# reconstruction error=0.0532519383200628, variation=5.094559829554868e-09.
# reconstruction error=0.0532519333113072, variation=5.008755604718473e-09.
# reconstruction error=0.05325192838682827, variation=4.924478928802767e-09.
# reconstruction error=0.053251923545191614, variation=4.841636654095982e-09.
# reconstruction error=0.053251918784867396, variation=4.7603242181448735e-09.
# reconstruction error=0.05325191410453262, variation=4.6803347725221656e-09.
# reconstruction error=0.05325190950276429, variation=4.601768334444589e-09.
# reconstruction error=0.053251904978162116, variation=4.524602172095715e-09.
# reconstruction error=0.053251900529432655, variation=4.448729461203893e-09.
# reconstruction error=0.05325189615521654, variation=4.374216114322316e-09.
# reconstruction error=0.053251891854258986, variation=4.300957555380958e-09.
# reconstruction error=0.05325188762521652, variation=4.2290424634439105e-09.
# reconstruction error=0.05325188346696622, variation=4.158250299646227e-09.
# reconstruction error=0.05325187937816461, variation=4.088801609791748e-09.
# reconstruction error=0.05325187535765693, variation=4.020507683721863e-09.
# reconstruction error=0.05325187140426565, variation=3.953391281008578e-09.
# reconstruction error=0.05325186751682009, variation=3.887445559902503e-09.
# reconstruction error=0.053251863694190466, variation=3.8226296225629675e-09.
# reconstruction error=0.053251859935262935, variation=3.758927530350675e-09.
# reconstruction error=0.053251856238937245, variation=3.6963256899724684e-09.
# reconstruction error=0.05325185260409501, variation=3.6348422327581176e-09.
# reconstruction error=0.05325184902973829, variation=3.574356720326133e-09.
# reconstruction error=0.0532518455147896, variation=3.5149486932173346e-09.
# reconstruction error=0.05325184205825782, variation=3.456531776080407e-09.
# reconstruction error=0.05325183865906774, variation=3.3991900821872534e-09.
# reconstruction error=0.053251835316344164, variation=3.3427235771044117e-09.
# reconstruction error=0.0532518320290278, variation=3.2873163635649405e-09.
# reconstruction error=0.05325182879621391, variation=3.232813891584918e-09.
# reconstruction error=0.053251825616972746, variation=3.17924116199908e-09.
# reconstruction error=0.05325182249037459, variation=3.126598153990745e-09.
# reconstruction error=0.053251819415487435, variation=3.074887157394901e-09.
# reconstruction error=0.053251816391474735, variation=3.0240126999703243e-09.
# reconstruction error=0.053251813417459035, variation=2.974015700374366e-09.
# reconstruction error=0.053251810492583346, variation=2.92487568887001e-09.
# reconstruction error=0.053251807615990666, variation=2.876592679335044e-09.
# reconstruction error=0.053251804786910384, variation=2.829080282540364e-09.
# reconstruction error=0.053251802004451405, variation=2.7824589785008236e-09.
# reconstruction error=0.05325179926788176, variation=2.7365696445014187e-09.
# reconstruction error=0.05325179657641266, variation=2.6914691031443283e-09.
# reconstruction error=0.05325179392928255, variation=2.6471301053931917e-09.
# reconstruction error=0.053251791325709494, variation=2.6035730585349803e-09.
# reconstruction error=0.0532517887649865, variation=2.5607229947599564e-09.
# reconstruction error=0.053251786246383874, variation=2.5186026250678673e-09.
# reconstruction error=0.05325178376916964, variation=2.4772142323548074e-09.
# reconstruction error=0.053251781332625474, variation=2.436544167816468e-09.
# reconstruction error=0.05325177893611943, variation=2.396506042223745e-09.
# reconstruction error=0.053251776578933166, variation=2.357186265622424e-09.
# reconstruction error=0.05325177426040747, variation=2.318525697819762e-09.
# reconstruction error=0.05325177197989219, variation=2.2805152766203207e-09.
# reconstruction error=0.053251769736741734, variation=2.2431504570485927e-09.
# reconstruction error=0.05325176753035826, variation=2.2063834717589437e-09.
# reconstruction error=0.053251765360121175, variation=2.1702370872622723e-09.
# reconstruction error=0.053251763225339435, variation=2.134781740270597e-09.
# reconstruction error=0.05325176112551292, variation=2.099826514057046e-09.
# reconstruction error=0.053251759060007425, variation=2.065505495807418e-09.
# reconstruction error=0.05325175702825009, variation=2.031757338760709e-09.
# reconstruction error=0.053251755029674885, variation=1.9985752011675295e-09.
# reconstruction error=0.05325175306372488, variation=1.965950006954653e-09.
# reconstruction error=0.05325175112987951, variation=1.933845368562448e-09.
# reconstruction error=0.05325174922755455, variation=1.902324957281376e-09.
# reconstruction error=0.05325174735622037, variation=1.8713341848330955e-09.
# reconstruction error=0.053251745515440485, variation=1.8407798826891586e-09.
# reconstruction error=0.05325174370463069, variation=1.8108097937785672e-09.
# reconstruction error=0.05325174192326361, variation=1.7813670816213545e-09.
# reconstruction error=0.053251740170932337, variation=1.7523312731415608e-09.
# reconstruction error=0.053251738447064004, variation=1.7238683328035798e-09.
# reconstruction error=0.05325173675123128, variation=1.6958327242466709e-09.
# reconstruction error=0.0532517350829886, variation=1.6682426828840136e-09.
# reconstruction error=0.053251733441824475, variation=1.641164121268801e-09.
# reconstruction error=0.05325173182736157, variation=1.614462903642977e-09.
# reconstruction error=0.053251730239058874, variation=1.5883026976970527e-09.
# reconstruction error=0.05325172867653901, variation=1.5625198634960924e-09.
# reconstruction error=0.05325172713935643, variation=1.537182582611596e-09.
# reconstruction error=0.0532517256271088, variation=1.5122476257345419e-09.
# reconstruction error=0.053251724139357366, variation=1.4877514359357136e-09.
# reconstruction error=0.05325172267571342, variation=1.4636439490955944e-09.
# reconstruction error=0.053251721235745036, variation=1.4399683806454178e-09.
# reconstruction error=0.053251719819124896, variation=1.4166201406373702e-09.
# reconstruction error=0.0532517184254188, variation=1.3937060949764657e-09.
# reconstruction error=0.05325171705422667, variation=1.3711921320602727e-09.
# reconstruction error=0.05325171570519161, variation=1.3490350572742393e-09.
# reconstruction error=0.05325171437797945, variation=1.3272121596186182e-09.
# reconstruction error=0.053251713072194666, variation=1.3057847858544136e-09.
# reconstruction error=0.05325171178753037, variation=1.2846642985508971e-09.
# reconstruction error=0.053251710523552355, variation=1.2639780125334177e-09.
# reconstruction error=0.053251709280003785, variation=1.2435485696737913e-09.
# reconstruction error=0.05325170805648228, variation=1.2235215063327587e-09.
# reconstruction error=0.053251706852719606, variation=1.2037626728744755e-09.
# reconstruction error=0.05325170566837477, variation=1.184344837479312e-09.
# reconstruction error=0.05325170450307043, variation=1.165304339134643e-09.
# reconstruction error=0.05325170335655653, variation=1.146513897709589e-09.
# reconstruction error=0.053251702228478456, variation=1.1280780753963882e-09.
# reconstruction error=0.0532517011185975, variation=1.1098809579723756e-09.
# reconstruction error=0.05325170002652724, variation=1.0920702606109778e-09.
# reconstruction error=0.0532516989520267, variation=1.0745005371570748e-09.
# reconstruction error=0.05325169789479809, variation=1.0572286102128459e-09.
# reconstruction error=0.0532516968545709, variation=1.0402271891085668e-09.
# reconstruction error=0.0532516958310678, variation=1.0235031017158391e-09.
# reconstruction error=0.05325169482400463, variation=1.0070631689673704e-09.
# reconstruction error=0.0532516938330427, variation=9.909619305692452e-10.
# reconstruction error=0.05325169285805695, variation=9.749857518559502e-10.
# reconstruction error=0.05325169189867461, variation=9.59382337462067e-10.
# reconstruction error=0.053251690954695605, variation=9.439790060739028e-10.
# reconstruction error=0.05325169002587217, variation=9.288234348314717e-10.
# reconstruction error=0.05325168911189742, variation=9.139747500497286e-10.
# reconstruction error=0.0532516882125804, variation=8.993170166893272e-10.
# reconstruction error=0.05325168732765743, variation=8.84922975175062e-10.
# reconstruction error=0.053251686456892086, variation=8.70765341776103e-10.
# reconstruction error=0.05325168560010932, variation=8.567827627925517e-10.
# reconstruction error=0.05325168475699999, variation=8.431093323491012e-10.
# reconstruction error=0.053251683927384504, variation=8.296154874187778e-10.
# reconstruction error=0.05325168311101963, variation=8.16364871536468e-10.
# reconstruction error=0.05325168230772579, variation=8.032938411672852e-10.
# reconstruction error=0.05325168151728246, variation=7.904433288463686e-10.
# reconstruction error=0.05325168073941234, variation=7.778701224814277e-10.
# reconstruction error=0.05325167997401538, variation=7.653969610887934e-10.
# reconstruction error=0.053251679220807445, variation=7.532079335237363e-10.
# reconstruction error=0.053251678479647596, variation=7.411598487716553e-10.
# reconstruction error=0.05325167775031986, variation=7.293277370923335e-10.
# reconstruction error=0.053251677032617385, variation=7.177024738402871e-10.
# reconstruction error=0.05325167632632422, variation=7.062931628443181e-10.
# reconstruction error=0.053251675631328974, variation=6.949952488510824e-10.
# reconstruction error=0.05325167494740204, variation=6.839269359182332e-10.
# reconstruction error=0.05325167427438204, variation=6.730200008409071e-10.
# reconstruction error=0.05325167361204163, variation=6.623404047445547e-10.
# reconstruction error=0.053251672960267164, variation=6.517744677303483e-10.
# reconstruction error=0.053251672318883614, variation=6.413835504370802e-10.
# reconstruction error=0.05325167168772046, variation=6.311631564615006e-10.
# reconstruction error=0.053251671066573136, variation=6.211473210782081e-10.
# reconstruction error=0.05325167045528477, variation=6.112883671471891e-10.
# reconstruction error=0.05325166985378719, variation=6.014975809098821e-10.
# reconstruction error=0.05325166926178486, variation=5.920023291028365e-10.
# reconstruction error=0.05325166867918231, variation=5.826025495370146e-10.
# reconstruction error=0.05325166810591133, variation=5.732709792982682e-10.
# reconstruction error=0.0532516675417037, variation=5.642076320033773e-10.
# reconstruction error=0.053251666986441216, variation=5.552624818272456e-10.
# reconstruction error=0.05325166643999428, variation=5.46446936311451e-10.
# reconstruction error=0.05325166590224242, variation=5.377518569327222e-10.
# reconstruction error=0.0532516653729697, variation=5.292727228711769e-10.
# reconstruction error=0.053251664852142, variation=5.208277004120632e-10.
# reconstruction error=0.053251664339597916, variation=5.125440835640482e-10.
# reconstruction error=0.0532516638351397, variation=5.044582182534008e-10.
# reconstruction error=0.05325166333869232, variation=4.964473762636423e-10.
# reconstruction error=0.053251662850089844, variation=4.886024779215958e-10.
# reconstruction error=0.05325166236925952, variation=4.808303269432379e-10.
# reconstruction error=0.0532516618960354, variation=4.732241196125919e-10.
# reconstruction error=0.05325166143029472, variation=4.657406751928939e-10.
# reconstruction error=0.05325166097193749, variation=4.583572341121389e-10.
# reconstruction error=0.05325166052085912, variation=4.5107836910140975e-10.
# reconstruction error=0.053251660076855015, variation=4.440041043163312e-10.
# reconstruction error=0.05325165963991382, variation=4.3694119156167943e-10.
# reconstruction error=0.05325165920987869, variation=4.300351325037255e-10.
# reconstruction error=0.053251658786635944, variation=4.2324274640570536e-10.
# reconstruction error=0.05325165837009921, variation=4.1653673565900107e-10.
# reconstruction error=0.05325165796012074, variation=4.0997846784129877e-10.
# reconstruction error=0.053251657556643676, variation=4.03477064259139e-10.
# reconstruction error=0.05325165715954757, variation=3.970961059973632e-10.
# reconstruction error=0.05325165676871191, variation=3.908356624449105e-10.
# reconstruction error=0.05325165638406396, variation=3.846479454394647e-10.
# reconstruction error=0.053251656005465074, variation=3.785988883509006e-10.
# reconstruction error=0.0532516556328334, variation=3.726316755159331e-10.
# reconstruction error=0.05325165526610756, variation=3.667258371975457e-10.
# reconstruction error=0.05325165490516935, variation=3.6093820987570524e-10.
# reconstruction error=0.053251654549930125, variation=3.552392269234872e-10.
# reconstruction error=0.05325165420023074, variation=3.4969938750295526e-10.
# reconstruction error=0.05325165385610758, variation=3.4412316052279124e-10.
# reconstruction error=0.053251653517403776, variation=3.3870380111711285e-10.
# reconstruction error=0.053251653184019324, variation=3.3338445198927147e-10.
# reconstruction error=0.053251652855895115, variation=3.2812420835970357e-10.
# reconstruction error=0.053251652532962955, variation=3.229321601794233e-10.
# reconstruction error=0.05325165221506144, variation=3.1790151761024177e-10.
# reconstruction error=0.053251651902222384, variation=3.1283905327361694e-10.
# reconstruction error=0.05325165159428215, variation=3.0794023581082186e-10.
# reconstruction error=0.0532516512911816, variation=3.031005516018759e-10.
# reconstruction error=0.053251650992873004, variation=2.9830859310520097e-10.
# reconstruction error=0.05325165069926544, variation=2.9360756187424286e-10.
# reconstruction error=0.053251650410245245, variation=2.8902019666432466e-10.
# reconstruction error=0.05325165012578513, variation=2.844601151852366e-10.
# reconstruction error=0.05325164984578509, variation=2.800000370450917e-10.
# reconstruction error=0.05325164957023149, variation=2.7555360077036184e-10.
# reconstruction error=0.05325164929897654, variation=2.712549490579974e-10.
# reconstruction error=0.053251649031997535, variation=2.6697900834538046e-10.
# reconstruction error=0.053251648769183084, variation=2.6281445075770904e-10.
# reconstruction error=0.05325164851050817, variation=2.586749148214551e-10.
# reconstruction error=0.05325164825591597, variation=2.5459220148738027e-10.
# reconstruction error=0.05325164800532237, variation=2.505935944863147e-10.
# reconstruction error=0.05325164775863189, variation=2.466904805431547e-10.
# reconstruction error=0.05325164751585819, variation=2.427737039178979e-10.
# reconstruction error=0.053251647276878505, variation=2.389796832646951e-10.
# reconstruction error=0.05325164704164281, variation=2.352356920365395e-10.
# reconstruction error=0.05325164681011702, variation=2.3152579159413378e-10.
# reconstruction error=0.05325164658219203, variation=2.279249913805792e-10.
# reconstruction error=0.053251646357845094, variation=2.2434693686124163e-10.
# reconstruction error=0.053251646137058024, variation=2.207870691828262e-10.
# reconstruction error=0.05325164591970353, variation=2.1735449551307795e-10.
# reconstruction error=0.053251645705763406, variation=2.1394012256203965e-10.
# reconstruction error=0.05325164549516267, variation=2.1060073823742087e-10.
# reconstruction error=0.053251645287903555, variation=2.0725911265007113e-10.
# reconstruction error=0.053251645083824704, variation=2.0407885104045675e-10.
# reconstruction error=0.05325164488297154, variation=2.008531674313474e-10.
# reconstruction error=0.05325164468526681, variation=1.9770472758917634e-10.
# reconstruction error=0.0532516444906832, variation=1.9458360617230497e-10.
# reconstruction error=0.05325164429912982, variation=1.9155338426557478e-10.
# reconstruction error=0.05325164411057254, variation=1.885572809001701e-10.
# reconstruction error=0.05325164392496818, variation=1.8560435827152943e-10.
# reconstruction error=0.053251643742278094, variation=1.8269008528193353e-10.
# reconstruction error=0.053251643562443184, variation=1.798349108517172e-10.
# reconstruction error=0.053251643385404335, variation=1.7703884885866827e-10.
# reconstruction error=0.05325164321114337, variation=1.7426096676764757e-10.
# reconstruction error=0.053251643039598916, variation=1.7154445225431303e-10.
# reconstruction error=0.053251642870770964, variation=1.688279516187663e-10.
# reconstruction error=0.0532516427045663, variation=1.6620466114503074e-10.
# reconstruction error=0.05325164254096905, variation=1.6359725379944123e-10.
# reconstruction error=0.05325164237990188, variation=1.6106716654862296e-10.
# reconstruction error=0.05325164222136028, variation=1.5854160345663004e-10.
# reconstruction error=0.05325164206529193, variation=1.5606834574688477e-10.
# reconstruction error=0.053251641911680955, variation=1.5361097810417945e-10.
# reconstruction error=0.05325164176047277, variation=1.5120818486202836e-10.
# reconstruction error=0.05325164161161965, variation=1.4885311733214834e-10.
# reconstruction error=0.0532516414650875, variation=1.4653215446580603e-10.
# reconstruction error=0.05325164132084448, variation=1.4424302030580094e-10.
# reconstruction error=0.05325164117887469, variation=1.419697900906236e-10.
# reconstruction error=0.05325164103908492, variation=1.3978977003725745e-10.
# reconstruction error=0.05325164090150245, variation=1.3758246625306114e-10.
# reconstruction error=0.05325164076605227, variation=1.3545017885085997e-10.
# reconstruction error=0.05325164063274574, variation=1.333065324793381e-10.
# reconstruction error=0.05325164050149193, variation=1.3125381337353303e-10.
# reconstruction error=0.053251640372313586, variation=1.2917834163461706e-10.
# reconstruction error=0.05325164024511066, variation=1.2720292874579542e-10.
# reconstruction error=0.053251640119899094, variation=1.252115633398887e-10.
# reconstruction error=0.05325163999666068, variation=1.2323841253047974e-10.
# reconstruction error=0.05325163987537497, variation=1.2128571064140559e-10.
# reconstruction error=0.05325163975591238, variation=1.194625925959869e-10.
# reconstruction error=0.053251639638359306, variation=1.1755307144367677e-10.
# reconstruction error=0.05325163952260663, variation=1.1575267827579339e-10.
# reconstruction error=0.05325163940867253, variation=1.1393409826698786e-10.
# reconstruction error=0.05325163929652065, variation=1.1215187806223881e-10.
# reconstruction error=0.05325163918613959, variation=1.1038105846017388e-10.
# reconstruction error=0.053251639077395274, variation=1.0874431910501414e-10.
# reconstruction error=0.053251638970405885, variation=1.0698938956998916e-10.
# reconstruction error=0.053251638865094125, variation=1.053117593130537e-10.
# reconstruction error=0.05325163876139637, variation=1.0369775871321707e-10.
# reconstruction error=0.05325163865932169, variation=1.0207467510126023e-10.
# reconstruction error=0.05325163855882236, variation=1.0049933107936226e-10.
# reconstruction error=0.053251638459921105, variation=9.89012552410351e-11.
# converged in 746 iterations.

# %%
nonneg_3_rand = parafac(sonar_tensor-sonar_tensor.min(),  # non-negative kruskal
                       rank = 3,
                       n_iter_max=50000, 
                       verbose=1, 
                       tol=1e-10,
                       init='svd',
                       normalize_factors=True,
                       non_negative=True)
# Out:
# reconstruction error=0.22191103990347116
# reconstruction error=0.20265756598684792, variation=0.019253473916623243.
# reconstruction error=0.1792881806246536, variation=0.023369385362194323.
# reconstruction error=0.1623103072746698, variation=0.016977873349983796.
# reconstruction error=0.15025961697920875, variation=0.012050690295461047.
# reconstruction error=0.14151901358004265, variation=0.008740603399166103.
# reconstruction error=0.13500652854126216, variation=0.006512485038780491.
# reconstruction error=0.13002659565712818, variation=0.004979932884133981.
# reconstruction error=0.1261282243211565, variation=0.0038983713359716787.
# reconstruction error=0.12301291217487813, variation=0.0031153121462783734.
# reconstruction error=0.12047819622501185, variation=0.002534715949866276.
# reconstruction error=0.11838328819444033, variation=0.002094908030571524.
# reconstruction error=0.11662792410305119, variation=0.0017553640913891416.
# reconstruction error=0.115139102513855, variation=0.0014888215891961931.
# reconstruction error=0.11386258750904425, variation=0.001276515004810741.
# reconstruction error=0.1127573417042099, variation=0.0011052458048343566.
# reconstruction error=0.11179179840853935, variation=0.0009655432956705429.
# reconstruction error=0.11094131287477159, variation=0.0008504855337677641.
# reconstruction error=0.11018638536525258, variation=0.0007549275095190128.
# reconstruction error=0.10951139961757143, variation=0.0006749857476811422.
# reconstruction error=0.10890371202959889, variation=0.0006076875879725413.
# reconstruction error=0.10835298375419966, variation=0.0005507282753992315.
# reconstruction error=0.10785068382736021, variation=0.0005022999268394501.
# reconstruction error=0.10738971458203589, variation=0.00046096924532432193.
# reconstruction error=0.10696412575015533, variation=0.0004255888318805551.
# reconstruction error=0.10656889374739326, variation=0.0003952320027620776.
# reconstruction error=0.10619974946406283, variation=0.00036914428333043037.
# reconstruction error=0.105853042574456, variation=0.00034670688960682094.
# reconstruction error=0.10552563364264766, variation=0.0003274089318083401.
# reconstruction error=0.10521480760487957, variation=0.00031082603776809437.
# reconstruction error=0.10491820385335685, variation=0.00029660375152272545.
# reconstruction error=0.1046337593326689, variation=0.0002844445206879459.
# reconstruction error=0.10435966192665234, variation=0.00027409740601655463.
# reconstruction error=0.10409431205196797, variation=0.00026534987468437854.
# reconstruction error=0.10383629084974974, variation=0.00025802120221822544.
# reconstruction error=0.10358433372353262, variation=0.0002519571262171172.
# reconstruction error=0.103337308241826, variation=0.000247025481706617.
# reconstruction error=0.10309419562996622, variation=0.00024311261185978872.
# reconstruction error=0.10285407523466307, variation=0.00024012039530314777.
# reconstruction error=0.10261611146727703, variation=0.00023796376738603742.
# reconstruction error=0.10237954282792865, variation=0.00023656863934838623.
# reconstruction error=0.10214367268769227, variation=0.0002358701402363772.
# reconstruction error=0.10190786156485508, variation=0.0002358111228371873.
# reconstruction error=0.10167152067872609, variation=0.00023634088612899118.
# reconstruction error=0.10143410660100335, variation=0.00023741407772273626.
# reconstruction error=0.10119511685413059, variation=0.00023898974687276697.
# reconstruction error=0.10095408632989117, variation=0.00024103052423941895.
# reconstruction error=0.10071058441928518, variation=0.00024350191060598658.
# reconstruction error=0.10046421275951231, variation=0.00024637165977287045.
# reconstruction error=0.10021460351509827, variation=0.0002496092444140424.
# reconstruction error=0.09996141811878795, variation=0.0002531853963103209.
# reconstruction error=0.09970434640449037, variation=0.000257071714297577.
# reconstruction error=0.09944310606953792, variation=0.0002612403349524506.
# reconstruction error=0.09917744240717499, variation=0.0002656636623629277.
# reconstruction error=0.09890712825308422, variation=0.0002703141540907755.
# reconstruction error=0.09863196409206425, variation=0.00027516416101996954.
# reconstruction error=0.09835177827277086, variation=0.0002801858192933854.
# reconstruction error=0.09806642728075016, variation=0.00028535099202070535.
# reconstruction error=0.097775796022077, variation=0.00029063125867315187.
# reconstruction error=0.0974797980727972, variation=0.00029599794927979983.
# reconstruction error=0.09717837585292, variation=0.0003014222198772093.
# reconstruction error=0.0968715006880554, variation=0.0003068751648645923.
# reconstruction error=0.09655917272735373, variation=0.0003123279607016721.
# reconstruction error=0.0962414206922565, variation=0.00031775203509723515.
# reconstruction error=0.095918301438448, variation=0.0003231192538084987.
# reconstruction error=0.09558989932085847, variation=0.00032840211758952687.
# reconstruction error=0.09525632536050033, variation=0.0003335739603581439.
# reconstruction error=0.09491771622046057, variation=0.00033860914003976117.
# reconstruction error=0.09457423300711512, variation=0.00034348321334544407.
# reconstruction error=0.09422605992051769, variation=0.00034817308659743085.
# reconstruction error=0.09387340278486667, variation=0.0003526571356510244.
# reconstruction error=0.09351648749528102, variation=0.00035691528958564644.
# reconstruction error=0.09315555842062442, variation=0.0003609290746565963.
# reconstruction error=0.09279087680289108, variation=0.0003646816177333423.
# reconstruction error=0.09242271919275293, variation=0.0003681576101381562.
# reconstruction error=0.09205137595651537, variation=0.0003713432362375535.
# reconstruction error=0.09167714988356863, variation=0.00037422607294673726.
# reconstruction error=0.09130035491515762, variation=0.0003767949684110178.
# reconstruction error=0.09092131500477713, variation=0.0003790399103804909.
# reconstruction error=0.09054036311019911, variation=0.00038095189457801326.
# reconstruction error=0.09015784030521946, variation=0.00038252280497964863.
# reconstruction error=0.08977409498962237, variation=0.0003837453155970949.
# reconstruction error=0.08938948216586048, variation=0.00038461282376188455.
# reconstruction error=0.08900436274519342, variation=0.00038511942066705995.
# reconstruction error=0.08861910284120056, variation=0.0003852599039928656.
# reconstruction error=0.08823407300864071, variation=0.00038502983255984946.
# reconstruction error=0.08784964738782593, variation=0.00038442562081478227.
# reconstruction error=0.08746620272087907, variation=0.00038344466694685553.
# reconstruction error=0.08708411721524908, variation=0.00038208550562998655.
# reconstruction error=0.08670376924048946, variation=0.00038034797475962334.
# reconstruction error=0.08632553585713469, variation=0.0003782333833547702.
# reconstruction error=0.08594979118912396, variation=0.00037574466801072737.
# reconstruction error=0.08557690466342271, variation=0.00037288652570124925.
# reconstruction error=0.08520723915111336, variation=0.00036966551230935285.
# reconstruction error=0.08484114905243914, variation=0.00036609009867422104.
# reconstruction error=0.08447897837367756, variation=0.0003621706787615836.
# reconstruction error=0.08412105884550101, variation=0.0003579195281765424.
# reconstruction error=0.08376770813143007, variation=0.00035335071407094354.
# reconstruction error=0.08341922817067342, variation=0.00034847996075665355.
# reconstruction error=0.0830759036927925, variation=0.00034332447788092135.
# reconstruction error=0.08273800093331628, variation=0.00033790275947621906.
# reconstruction error=0.08240576656971627, variation=0.0003322343636000119.
# reconstruction error=0.08207942688761843, variation=0.0003263396820978315.
# reconstruction error=0.08175918717796622, variation=0.00032023970965221193.
# reconstruction error=0.08144523135776596, variation=0.0003139558202002596.
# reconstruction error=0.08113772180077855, variation=0.000307509556987412.
# reconstruction error=0.08083679936012507, variation=0.00030092244065348106.
# reconstruction error=0.08054258356142154, variation=0.0002942157987035343.
# reconstruction error=0.08025517294485617, variation=0.00028741061656537004.
# reconstruction error=0.07997464553419509, variation=0.0002805274106610772.
# reconstruction error=0.07970105941272637, variation=0.0002735861214687163.
# reconstruction error=0.07943445338806662, variation=0.00026660602465974903.
# reconstruction error=0.07917484773006832, variation=0.0002596056579983047.
# reconstruction error=0.07892224496897034, variation=0.00025260276109798085.
# reconstruction error=0.07867663074275301, variation=0.00024561422621732776.
# reconstruction error=0.0784379746848305, variation=0.00023865605792250388.
# reconstruction error=0.07820623134441547, variation=0.00023174334041503597.
# reconstruction error=0.07798134113297375, variation=0.00022489021144171673.
# reconstruction error=0.0777632312905897, variation=0.0002181098423840594.
# reconstruction error=0.07755181686637627, variation=0.00021141442421342138.
# reconstruction error=0.07734700170669698, variation=0.00020481515967929464.
# reconstruction error=0.07714867944547679, variation=0.00019832226122018515.
# reconstruction error=0.07695673449005751, variation=0.0001919449554192848.
# reconstruction error=0.07677104299631227, variation=0.00018569149374524085.
# reconstruction error=0.07659147382696119, variation=0.00017956916935107925.
# reconstruction error=0.0764178894869637, variation=0.0001735843399974929.
# reconstruction error=0.07625014703034859, variation=0.00016774245661510534.
# reconstruction error=0.07608809893351214, variation=0.0001620480968364535.
# reconstruction error=0.07593159393066948, variation=0.0001565050028426579.
# reconstruction error=0.0757804778076029, variation=0.0001511161230665775.
# reconstruction error=0.07563459415117196, variation=0.00014588365643093681.
# reconstruction error=0.07549378505245709, variation=0.00014080909871487524.
# reconstruction error=0.07535789176207988, variation=0.00013589329037720643.
# reconstruction error=0.07522675529765943, variation=0.00013113646442045046.
# reconstruction error=0.0751002170030052, variation=0.00012653829465422706.
# reconstruction error=0.07497811905999602, variation=0.0001220979430091862.
# reconstruction error=0.07486030495418233, variation=0.00011781410581368501.
# reconstruction error=0.07474661989550367, variation=0.00011368505867866141.
# reconstruction error=0.07463691119588593, variation=0.00010970869961773877.
# reconstruction error=0.07453102860561346, variation=0.00010588259027247138.
# reconstruction error=0.07442882461036825, variation=0.00010220399524521473.
# reconstruction error=0.07433015469111896, variation=9.866991924928348e-05.
# reconstruction error=0.07423487754896105, variation=9.527714215791516e-05.
# reconstruction error=0.07414285529667505, variation=9.202225228599481e-05.
# reconstruction error=0.07405395361940262, variation=8.890167727243492e-05.
# reconstruction error=0.07396804190608937, variation=8.591171331324976e-05.
# reconstruction error=0.07388499335379915, variation=8.30485522902158e-05.
# reconstruction error=0.07380468504655893, variation=8.030830724022053e-05.
# reconstruction error=0.0737269980106832, variation=7.76870358757259e-05.
# reconstruction error=0.07365181724813441, variation=7.518076254879602e-05.
# reconstruction error=0.07357903174981181, variation=7.278549832259729e-05.
# reconstruction error=0.07350853449021798, variation=7.049725959383524e-05.
# reconstruction error=0.07344022240509389, variation=6.831208512408926e-05.
# reconstruction error=0.07337399635383383, variation=6.622605126005432e-05.
# reconstruction error=0.07330976106783635, variation=6.42352859974854e-05.
# reconstruction error=0.07324742508650818, variation=6.23359813281682e-05.
# reconstruction error=0.07318690068232088, variation=6.0524404187300984e-05.
# reconstruction error=0.07312810377622479, variation=5.87969060960869e-05.
# reconstruction error=0.0730709538447725, variation=5.714993145229663e-05.
# reconstruction error=0.07301537382039078, variation=5.5580024381718385e-05.
# reconstruction error=0.07296128998572275, variation=5.4083834668025577e-05.
# reconstruction error=0.07290863186350428, variation=5.265812221846855e-05.
# reconstruction error=0.072857332102829, variation=5.129976067527742e-05.
# reconstruction error=0.07280732636286852, variation=5.0005739960487516e-05.
# reconstruction error=0.07275855319515415, variation=4.877316771437212e-05.
# reconstruction error=0.07271095392486472, variation=4.759927028942512e-05.
# reconstruction error=0.07266447253237572, variation=4.648139248900063e-05.
# reconstruction error=0.0726190555354505, variation=4.54169969252155e-05.
# reconstruction error=0.07257465187268491, variation=4.440366276559082e-05.
# reconstruction error=0.07253121278888429, variation=4.3439083800625444e-05.
# reconstruction error=0.07248869172284138, variation=4.252106604291095e-05.
# reconstruction error=0.07244704419764281, variation=4.1647525198570956e-05.
# reconstruction error=0.07240622771425971, variation=4.0816483383096513e-05.
# reconstruction error=0.07236620164818326, variation=4.002606607644843e-05.
# reconstruction error=0.07232692714977317, variation=3.927449841009678e-05.
# reconstruction error=0.07228836704818929, variation=3.856010158387324e-05.
# reconstruction error=0.07225048575904454, variation=3.7881289144753305e-05.
# reconstruction error=0.07221324919602347, variation=3.723656302107026e-05.
# reconstruction error=0.07217662468613707, variation=3.6624509886395984e-05.
# reconstruction error=0.0721405808891322, variation=3.604379700487825e-05.
# reconstruction error=0.07210508772042401, variation=3.5493168708183864e-05.
# reconstruction error=0.07207011627800211, variation=3.4971442421899424e-05.
# reconstruction error=0.07203563877295557, variation=3.447750504653735e-05.
# reconstruction error=0.07200162846350544, variation=3.401030945013317e-05.
# reconstruction error=0.07196805959275915, variation=3.356887074629222e-05.
# reconstruction error=0.07193490732961896, variation=3.315226314018482e-05.
# reconstruction error=0.07190214771309526, variation=3.275961652370041e-05.
# reconstruction error=0.0718697575996579, variation=3.2390113437363866e-05.
# reconstruction error=0.07183771461379129, variation=3.204298586660659e-05.
# reconstruction error=0.07180599710117637, variation=3.171751261492328e-05.
# reconstruction error=0.07177458408486621, variation=3.1413016310155584e-05.
# reconstruction error=0.0717434552239974, variation=3.112886086881206e-05.
# reconstruction error=0.07171259077497442, variation=3.0864449022977025e-05.
# reconstruction error=0.07168197155520178, variation=3.061921977264015e-05.
# reconstruction error=0.0716515789089793, variation=3.039264622248239e-05.
# reconstruction error=0.0716213946755702, variation=3.0184233409100147e-05.
# reconstruction error=0.07159140115950405, variation=2.999351606615408e-05.
# reconstruction error=0.07156158110264024, variation=2.9820056863805178e-05.
# reconstruction error=0.07153191765829076, variation=2.9663444349486978e-05.
# reconstruction error=0.07150239436701827, variation=2.9523291272481877e-05.
# reconstruction error=0.07147299513422961, variation=2.9399232788662744e-05.
# reconstruction error=0.07144370420936143, variation=2.92909248681833e-05.
# reconstruction error=0.07141450616660254, variation=2.919804275888782e-05.
# reconstruction error=0.07138538588722437, variation=2.912027937816697e-05.
# reconstruction error=0.07135632854314593, variation=2.905734407844529e-05.
# reconstruction error=0.07132731958204115, variation=2.9008961104776132e-05.
# reconstruction error=0.07129834471360184, variation=2.8974868439307633e-05.
# reconstruction error=0.07126938989727388, variation=2.8954816327961264e-05.
# reconstruction error=0.07124044133088853, variation=2.8948566385356145e-05.
# reconstruction error=0.07121148544074384, variation=2.8955890144691243e-05.
# reconstruction error=0.07118250887259438, variation=2.8976568149458037e-05.
# reconstruction error=0.07115349848381193, variation=2.901038878244666e-05.
# reconstruction error=0.07112444133659078, variation=2.9057147221150936e-05.
# reconstruction error=0.07109532469203177, variation=2.9116644559012972e-05.
# reconstruction error=0.07106613600530787, variation=2.9188686723899404e-05.
# reconstruction error=0.0710368629216244, variation=2.9273083683473144e-05.
# reconstruction error=0.07100749327327381, variation=2.9369648350582866e-05.
# reconstruction error=0.07097801507722468, variation=2.947819604913471e-05.
# reconstruction error=0.07094841653382941, variation=2.959854339526502e-05.
# reconstruction error=0.07091868602627949, variation=2.9730507549924345e-05.
# reconstruction error=0.07088881212056872, variation=2.9873905710769977e-05.
# reconstruction error=0.07085878356653638, variation=3.0028554032335286e-05.
# reconstruction error=0.07082858929942823, variation=3.0194267108152317e-05.
# reconstruction error=0.07079821844214786, variation=3.0370857280373476e-05.
# reconstruction error=0.07076766030821645, variation=3.0558133931407605e-05.
# reconstruction error=0.07073690440530087, variation=3.0755902915582944e-05.
# reconstruction error=0.07070594043942574, variation=3.0963965875124844e-05.
# reconstruction error=0.07067475831962985, variation=3.118211979588614e-05.
# reconstruction error=0.07064334816331086, variation=3.141015631899502e-05.
# reconstruction error=0.07061170030197063, variation=3.164786134023101e-05.
# reconstruction error=0.07057980528749579, variation=3.1895014474842e-05.
# reconstruction error=0.07054765389898009, variation=3.2151388515699875e-05.
# reconstruction error=0.07051523714987039, variation=3.241674910969827e-05.
# reconstruction error=0.07048254629557103, variation=3.2690854299355365e-05.
# reconstruction error=0.0704495728415237, variation=3.2973454047333095e-05.
# reconstruction error=0.07041630855138577, variation=3.326429013793264e-05.
# reconstruction error=0.0703827454559665, variation=3.356309541927005e-05.
# reconstruction error=0.07034887586201857, variation=3.386959394792444e-05.
# reconstruction error=0.07031469236164173, variation=3.4183500376844256e-05.
# reconstruction error=0.07028018784176564, variation=3.4504519876091266e-05.
# reconstruction error=0.07024535549390168, variation=3.483234786395839e-05.
# reconstruction error=0.07021018882419078, variation=3.516666971090099e-05.
# reconstruction error=0.0701746816633432, variation=3.5507160847575436e-05.
# reconstruction error=0.07013882817710898, variation=3.585348623422191e-05.
# reconstruction error=0.07010262287649172, variation=3.620530061726468e-05.
# reconstruction error=0.07006606062831024, variation=3.656224818147924e-05.
# reconstruction error=0.07002913666569965, variation=3.692396261058273e-05.
# reconstruction error=0.06999184659862309, variation=3.7290067076561906e-05.
# reconstruction error=0.06995418642437005, variation=3.766017425303747e-05.
# reconstruction error=0.0699161525382044, variation=3.8033886165647623e-05.
# reconstruction error=0.06987774174360496, variation=3.841079459944441e-05.
# reconstruction error=0.06983895126279756, variation=3.879048080740466e-05.
# reconstruction error=0.0697997787468288, variation=3.9172515968757815e-05.
# reconstruction error=0.06976022228566396, variation=3.9556461164838574e-05.
# reconstruction error=0.06972028041809032, variation=3.99418675736396e-05.
# reconstruction error=0.06967995214131183, variation=4.0328276778495153e-05.
# reconstruction error=0.06963923692031741, variation=4.0715220994413936e-05.
# reconstruction error=0.0695981346970717, variation=4.1102223245714775e-05.
# reconstruction error=0.06955664589916676, variation=4.1488797904942754e-05.
# reconstruction error=0.06951477144826461, variation=4.1874450902146254e-05.
# reconstruction error=0.06947251276822416, variation=4.2258680040443974e-05.
# reconstruction error=0.06942987179248476, variation=4.264097573940251e-05.
# reconstruction error=0.06938685097137544, variation=4.302082110932415e-05.
# reconstruction error=0.06934345327863418, variation=4.3397692741253824e-05.
# reconstruction error=0.06929968221747453, variation=4.3771061159658675e-05.
# reconstruction error=0.06925554182608717, variation=4.414039138735115e-05.
# reconstruction error=0.06921103668259337, variation=4.4505143493800414e-05.
# reconstruction error=0.0691661719091631, variation=4.4864773430269844e-05.
# reconstruction error=0.06912095317553409, variation=4.521873362901829e-05.
# reconstruction error=0.06907538670192022, variation=4.556647361386723e-05.
# reconstruction error=0.0690294792608569, variation=4.590744106332256e-05.
# reconstruction error=0.06898323817851021, variation=4.6241082346687445e-05.
# reconstruction error=0.06893667133493628, variation=4.6566843573930816e-05.
# reconstruction error=0.0688897871635408, variation=4.688417139547818e-05.
# reconstruction error=0.06884259464959855, variation=4.7192513942251324e-05.
# reconstruction error=0.06879510332781939, variation=4.7491321779155604e-05.
# reconstruction error=0.06874732327864856, variation=4.778004917083134e-05.
# reconstruction error=0.06869926512404625, variation=4.805815460230678e-05.
# reconstruction error=0.06865094002161086, variation=4.832510243539534e-05.
# reconstruction error=0.068602359657918, variation=4.858036369286001e-05.
# reconstruction error=0.06855353624069392, variation=4.8823417224078125e-05.
# reconstruction error=0.06850448248960135, variation=4.9053751092570375e-05.
# reconstruction error=0.06845521162612958, variation=4.927086347177034e-05.
# reconstruction error=0.0684057373619146, variation=4.9474264214977026e-05.
# reconstruction error=0.06835607388608474, variation=4.9663475829866965e-05.
# reconstruction error=0.06830623585122401, variation=4.9838034860721914e-05.
# reconstruction error=0.06825623835805181, variation=4.9997493172207474e-05.
# reconstruction error=0.06820609693876548, variation=5.0141419286331423e-05.
# reconstruction error=0.06815582753930291, variation=5.026939946256581e-05.
# reconstruction error=0.06810544650002663, variation=5.0381039276278794e-05.
# reconstruction error=0.06805497053540759, variation=5.047596461904558e-05.
# reconstruction error=0.06800441671224389, variation=5.055382316369872e-05.
# reconstruction error=0.06795380242670941, variation=5.0614285534475445e-05.
# reconstruction error=0.06790314538026543, variation=5.065704644398317e-05.
# reconstruction error=0.06785246355424389, variation=5.06818260215397e-05.
# reconstruction error=0.06780177518348876, variation=5.068837075512811e-05.
# reconstruction error=0.06775109872862267, variation=5.067645486608874e-05.
# reconstruction error=0.06770045284763694, variation=5.064588098573075e-05.
# reconstruction error=0.06764985636622015, variation=5.059648141679529e-05.
# reconstruction error=0.06759932824735933, variation=5.0528118860818094e-05.
# reconstruction error=0.06754888756003873, variation=5.044068732060203e-05.
# reconstruction error=0.0674985534472407, variation=5.0334112798020025e-05.
# reconstruction error=0.06744834509329682, variation=5.020835394388412e-05.
# reconstruction error=0.0673982816907121, variation=5.006340258471853e-05.
# reconstruction error=0.06734838240645151, variation=4.989928426059331e-05.
# reconstruction error=0.06729866634809757, variation=4.9716058353938e-05.
# reconstruction error=0.06724915252955818, variation=4.9513818539390075e-05.
# reconstruction error=0.06719985983681499, variation=4.929269274318859e-05.
# reconstruction error=0.06715080699368695, variation=4.905284312804736e-05.
# reconstruction error=0.0671020125276701, variation=4.879446601684101e-05.
# reconstruction error=0.06705349473616591, variation=4.851779150419344e-05.
# reconstruction error=0.0670052716529503, variation=4.822308321561497e-05.
# reconstruction error=0.06695736101537336, variation=4.791063757693392e-05.
# reconstruction error=0.0669097802320506, variation=4.758078332275928e-05.
# reconstruction error=0.06686254635147446, variation=4.7233880576147413e-05.
# reconstruction error=0.06681567603138125, variation=4.687032009320635e-05.
# reconstruction error=0.06676918550936063, variation=4.649052202061743e-05.
# reconstruction error=0.0667230905744341, variation=4.609493492653549e-05.
# reconstruction error=0.06667740653998988, variation=4.568403444421554e-05.
# reconstruction error=0.06663214821809366, variation=4.525832189622436e-05.
# reconstruction error=0.06658732989525054, variation=4.481832284311538e-05.
# reconstruction error=0.06654296530968196, variation=4.43645855685848e-05.
# reconstruction error=0.06649906763036606, variation=4.3897679315896276e-05.
# reconstruction error=0.06645564943775562, variation=4.3418192610444883e-05.
# reconstruction error=0.06641272270619474, variation=4.2926731560880005e-05.
# reconstruction error=0.066370298788323, variation=4.2423917871736716e-05.
# reconstruction error=0.06632838840137423, variation=4.1910386948770806e-05.
# reconstruction error=0.0662870016152148, variation=4.1386786159433586e-05.
# reconstruction error=0.06624614784259546, variation=4.085377261933698e-05.
# reconstruction error=0.06620583583119603, variation=4.031201139942375e-05.
# reconstruction error=0.06616607365777026, variation=3.9762173425772485e-05.
# reconstruction error=0.06612686872412193, variation=3.9204933648326334e-05.
# reconstruction error=0.06608822775515473, variation=3.864096896720459e-05.
# reconstruction error=0.06605015679879622, variation=3.8070956358507435e-05.
# reconstruction error=0.06601266122786924, variation=3.7495570926984745e-05.
# reconstruction error=0.06597574574361897, variation=3.6915484250263364e-05.
# reconstruction error=0.06593941438137593, variation=3.6331362243041676e-05.
# reconstruction error=0.06590367051747646, variation=3.5743863899470596e-05.
# reconstruction error=0.06586851687826027, variation=3.515363921618997e-05.
# reconstruction error=0.0658339555504977, variation=3.456132776256948e-05.
# reconstruction error=0.06579998799314081, variation=3.396755735689261e-05.
# reconstruction error=0.06576661505066136, variation=3.3372942479445444e-05.
# reconstruction error=0.065733836967751, variation=3.277808291037021e-05.
# reconstruction error=0.06570165340499916, variation=3.2183562751836314e-05.
# reconstruction error=0.06567006345587748, variation=3.158994912168256e-05.
# reconstruction error=0.06563906566460775, variation=3.099779126972124e-05.
# reconstruction error=0.06560865804502336, variation=3.0407619584393863e-05.
# reconstruction error=0.06557883810018197, variation=2.981994484138606e-05.
# reconstruction error=0.0655496028426369, variation=2.923525754507106e-05.
# reconstruction error=0.06552094881532834, variation=2.8654027308561147e-05.
# reconstruction error=0.06549287211295615, variation=2.8076702372190065e-05.
# reconstruction error=0.06546536840378162, variation=2.7503709174536706e-05.
# reconstruction error=0.06543843295151179, variation=2.6935452269824522e-05.
# reconstruction error=0.06541206063768946, variation=2.6372313822325966e-05.
# reconstruction error=0.06538624598396299, variation=2.5814653726474734e-05.
# reconstruction error=0.06536098317430274, variation=2.5262809660253627e-05.
# reconstruction error=0.06533626607738144, variation=2.4717096921297865e-05.
# reconstruction error=0.06531208826858564, variation=2.4177808795794453e-05.
# reconstruction error=0.06528844305197112, variation=2.364521661452068e-05.
# reconstruction error=0.06526532348178664, variation=2.311957018448496e-05.
# reconstruction error=0.0652427223836861, variation=2.2601098100538675e-05.
# reconstruction error=0.06522063237562786, variation=2.209000805823702e-05.
# reconstruction error=0.06519904588802697, variation=2.158648760089421e-05.
# reconstruction error=0.06517795518383969, variation=2.109070418727932e-05.
# reconstruction error=0.0651573523776029, variation=2.0602806236794113e-05.
# reconstruction error=0.06513722945423953, variation=2.0122923363369294e-05.
# reconstruction error=0.06511757828711515, variation=1.965116712437931e-05.
# reconstruction error=0.06509839065536818, variation=1.918763174696414e-05.
# reconstruction error=0.06507965826071954, variation=1.8732394648640627e-05.
# reconstruction error=0.0650613727434599, variation=1.8285517259644668e-05.
# reconstruction error=0.06504352569783532, variation=1.7847045624574953e-05.
# reconstruction error=0.06502610868664155, variation=1.7417011193773813e-05.
# reconstruction error=0.065009113255198, variation=1.699543144355331e-05.
# reconstruction error=0.06499253094441144, variation=1.658231078655037e-05.
# reconstruction error=0.06497635330340476, variation=1.6177641006684396e-05.
# reconstruction error=0.06496057190121031, variation=1.578140219445079e-05.
# reconstruction error=0.06494517833784778, variation=1.539356336252573e-05.
# reconstruction error=0.06493016425463446, variation=1.5014083213318874e-05.
# reconstruction error=0.06491552134394961, variation=1.4642910684856125e-05.
# reconstruction error=0.06490124135824192, variation=1.427998570768807e-05.
# reconstruction error=0.06488731611834712, variation=1.3925239894796437e-05.
# reconstruction error=0.06487373752124824, variation=1.3578597098884426e-05.
# reconstruction error=0.06486049754722108, variation=1.3239974027162704e-05.
# reconstruction error=0.06484758826632059, variation=1.2909280900488818e-05.
# reconstruction error=0.06483500184433949, variation=1.2586421981097828e-05.
# reconstruction error=0.06482273054819127, variation=1.2271296148225197e-05.
# reconstruction error=0.06481076675083433, variation=1.1963797356934203e-05.
# reconstruction error=0.06479910293554067, variation=1.1663815293661006e-05.
# reconstruction error=0.06478773169985153, variation=1.1371235689144887e-05.
# reconstruction error=0.06477664575894179, variation=1.1085940909733027e-05.
# reconstruction error=0.06476583794861822, variation=1.0807810323573697e-05.
# reconstruction error=0.0647553012278526, variation=1.053672076561929e-05.
# reconstruction error=0.06474502868098174, variation=1.0272546870859767e-05.
# reconstruction error=0.06473501351947189, variation=1.0015161509849269e-05.
# reconstruction error=0.0647252490833573, variation=9.76443611458433e-06.
# reconstruction error=0.06471572884233831, variation=9.520241018995401e-06.
# reconstruction error=0.06470644639665082, variation=9.282445687486263e-06.
# reconstruction error=0.06469739547755246, variation=9.050919098363419e-06.
# reconstruction error=0.0646885699474868, variation=8.825530065662002e-06.
# reconstruction error=0.06467996380021794, variation=8.606147268858111e-06.
# reconstruction error=0.06467157116051091, variation=8.3926397070333e-06.
# reconstruction error=0.06466338628369851, variation=8.184876812394881e-06.
# reconstruction error=0.06465540355506216, variation=7.982728636349301e-06.
# reconstruction error=0.06464761748897987, variation=7.786066082288157e-06.
# reconstruction error=0.06464002272795984, variation=7.59476102003831e-06.
# reconstruction error=0.06463261404139888, variation=7.408686560961275e-06.
# reconstruction error=0.06462538632449108, variation=7.227716907795556e-06.
# reconstruction error=0.06461833459662586, variation=7.0517278652204585e-06.
# reconstruction error=0.06461145399999137, variation=6.880596634492586e-06.
# reconstruction error=0.0646047397979282, variation=6.714202063162755e-06.
# reconstruction error=0.06459818737315019, variation=6.552424778011323e-06.
# reconstruction error=0.06459179222605145, variation=6.3951470987422265e-06.
# reconstruction error=0.06458554997283429, variation=6.242253217159099e-06.
# reconstruction error=0.06457945634349929, variation=6.093629334999462e-06.
# reconstruction error=0.0645735071800093, variation=5.949163489990528e-06.
# reconstruction error=0.06456769843418109, variation=5.8087458282146676e-06.
# reconstruction error=0.06456202616566542, variation=5.672268515666268e-06.
# reconstruction error=0.06455648653985434, variation=5.53962581108236e-06.
# reconstruction error=0.06455107582580584, variation=5.410714048498244e-06.
# reconstruction error=0.06454579039412861, variation=5.285431677229391e-06.
# reconstruction error=0.0645406267148058, variation=5.163679322808812e-06.
# reconstruction error=0.0645355813551201, variation=5.045359685706963e-06.
# reconstruction error=0.06453065097741527, variation=4.930377704825961e-06.
# reconstruction error=0.06452583233716012, variation=4.818640255144224e-06.
# reconstruction error=0.0645211222805665, variation=4.710056593623668e-06.
# reconstruction error=0.06451651774266925, variation=4.604537897245908e-06.
# reconstruction error=0.06451201574508848, variation=4.501997580771966e-06.
# reconstruction error=0.06450761339409493, variation=4.402350993554238e-06.
# reconstruction error=0.06450330787835398, variation=4.305515740946064e-06.
# reconstruction error=0.0644990964670298, variation=4.211411324187009e-06.
# reconstruction error=0.0644949765077297, variation=4.119959300094567e-06.
# reconstruction error=0.0644909454244245, variation=4.031083305197636e-06.
# reconstruction error=0.06448700071560348, variation=3.944708821021492e-06.
# reconstruction error=0.06448313995220856, variation=3.860763394925026e-06.
# reconstruction error=0.06447936077586176, variation=3.7791763467937e-06.
# reconstruction error=0.06447566089686281, variation=3.6998789989528547e-06.
# reconstruction error=0.06447203809242773, variation=3.6228044350827826e-06.
# reconstruction error=0.06446849020479348, variation=3.5478876342504018e-06.
# reconstruction error=0.06446501513958292, variation=3.475065210561956e-06.
# reconstruction error=0.0644616108638895, variation=3.404275693411063e-06.
# reconstruction error=0.06445827540467698, variation=3.335459212522318e-06.
# reconstruction error=0.06445500684707747, variation=3.2685575995089478e-06.
# reconstruction error=0.06445180333277199, variation=3.2035143054803816e-06.
# reconstruction error=0.06444866305836719, variation=3.140274404803134e-06.
# reconstruction error=0.06444558427382656, variation=3.078784540630486e-06.
# reconstruction error=0.06444256528097507, variation=3.0189928514889885e-06.
# reconstruction error=0.06443960443195335, variation=2.960849021724221e-06.
# reconstruction error=0.0644367001278205, variation=2.9043041328419283e-06.
# reconstruction error=0.06443385081709548, variation=2.8493107250282534e-06.
# reconstruction error=0.06443105499435886, variation=2.795822736614828e-06.
# reconstruction error=0.06442831119891357, variation=2.743795445292463e-06.
# reconstruction error=0.0644256180135214, variation=2.693185392171893e-06.
# reconstruction error=0.06442297406300851, variation=2.6439505128872387e-06.
# reconstruction error=0.06442037801313505, variation=2.596049873460071e-06.
# reconstruction error=0.06441782856927168, variation=2.5494438633671956e-06.
# reconstruction error=0.06441532447526901, variation=2.5040940026671565e-06.
# reconstruction error=0.06441286451232957, variation=2.459962939446725e-06.
# reconstruction error=0.06441044749785643, variation=2.4170144731355814e-06.
# reconstruction error=0.06440807228435741, variation=2.3752134990229212e-06.
# reconstruction error=0.0644057377583803, variation=2.334525977115698e-06.
# reconstruction error=0.06440344283954702, variation=2.294918833273263e-06.
# reconstruction error=0.06440118647947242, variation=2.2563600746011714e-06.
# reconstruction error=0.06439896766083075, variation=2.21881864166662e-06.
# reconstruction error=0.0643967853964217, variation=2.182264409053558e-06.
# reconstruction error=0.06439463872829007, variation=2.1466681316278935e-06.
# reconstruction error=0.06439252672673801, variation=2.1120015520625923e-06.
# reconstruction error=0.06439044848953755, variation=2.078237200456301e-06.
# reconstruction error=0.06438840314109963, variation=2.0453484379234776e-06.
# reconstruction error=0.06438638983164248, variation=2.0133094571495036e-06.
# reconstruction error=0.06438440773641596, variation=1.9820952265187097e-06.
# reconstruction error=0.06438245605489731, variation=1.951681518647108e-06.
# reconstruction error=0.06438053401011615, variation=1.92204478116631e-06.
# reconstruction error=0.06437864084792838, variation=1.8931621877660287e-06.
# reconstruction error=0.06437677583627645, variation=1.8650116519330906e-06.
# reconstruction error=0.06437493826456785, variation=1.8375717086016596e-06.
# reconstruction error=0.06437312744293465, variation=1.8108216331969018e-06.
# reconstruction error=0.06437134270180504, variation=1.7847411296068039e-06.
# reconstruction error=0.06436958339101001, variation=1.7593107950325537e-06.
# reconstruction error=0.06436784887942933, variation=1.7345115806838285e-06.
# reconstruction error=0.06436613855433285, variation=1.7103250964795036e-06.
# reconstruction error=0.06436445182072327, variation=1.6867336095766072e-06.
# reconstruction error=0.06436278810098707, variation=1.6637197362001643e-06.
# reconstruction error=0.06436114683423495, variation=1.6412667521170654e-06.
# reconstruction error=0.06435952747589788, variation=1.619358337076604e-06.
# reconstruction error=0.06435792949706887, variation=1.5979788290099162e-06.
# reconstruction error=0.06435635238426607, variation=1.5771128027974868e-06.
# reconstruction error=0.06435479563876288, variation=1.5567455031867405e-06.
# reconstruction error=0.06435325877629607, variation=1.536862466816613e-06.
# reconstruction error=0.06435174132651404, variation=1.5174497820236166e-06.
# reconstruction error=0.06435024283264712, variation=1.4984938669221348e-06.
# reconstruction error=0.06434876285111904, variation=1.4799815280797102e-06.
# reconstruction error=0.06434730095099118, variation=1.461900127855409e-06.
# reconstruction error=0.06434585671386356, variation=1.4442371276263133e-06.
# reconstruction error=0.06434442973323035, variation=1.426980633212338e-06.
# reconstruction error=0.06434301961428467, variation=1.4101189456799945e-06.
# reconstruction error=0.06434162597356914, variation=1.3936407155246133e-06.
# reconstruction error=0.06434024843855297, variation=1.3775350161671085e-06.
# reconstruction error=0.06433888664739316, variation=1.361791159809611e-06.
# reconstruction error=0.06433754024858851, variation=1.3463988046552577e-06.
# reconstruction error=0.06433620890070874, variation=1.3313478797738476e-06.
# reconstruction error=0.06433489227202001, variation=1.3166286887272838e-06.
# reconstruction error=0.06433359004030044, variation=1.3022317195687805e-06.
# reconstruction error=0.06433230189246543, variation=1.2881478350101894e-06.
# reconstruction error=0.06433102752440749, variation=1.274368057940789e-06.
# reconstruction error=0.06432976664062143, variation=1.260883786061151e-06.
# reconstruction error=0.06432851895404963, variation=1.2476865717953034e-06.
# reconstruction error=0.06432728418576927, variation=1.2347682803587334e-06.
# reconstruction error=0.06432606206479785, variation=1.2221209714224912e-06.
# reconstruction error=0.06432485232781421, variation=1.2097369836427951e-06.
# reconstruction error=0.06432365471899786, variation=1.1976088163528908e-06.
# reconstruction error=0.06432246898975727, variation=1.1857292405853537e-06.
# reconstruction error=0.0643212948985297, variation=1.1740912275737259e-06.
# reconstruction error=0.06432013221059403, variation=1.1626879356657627e-06.
# reconstruction error=0.06431898069783844, variation=1.1515127555927762e-06.
# reconstruction error=0.06431784013862214, variation=1.1405592162949674e-06.
# reconstruction error=0.06431671031752599, variation=1.129821096151895e-06.
# reconstruction error=0.0643155910251784, variation=1.1192923475844552e-06.
# reconstruction error=0.0643144820581207, variation=1.108967057711352e-06.
# reconstruction error=0.0643133832185745, variation=1.09883954620138e-06.
# reconstruction error=0.06431229431430142, variation=1.088904273069402e-06.
# reconstruction error=0.06431121515847585, variation=1.0791558255757172e-06.
# reconstruction error=0.06431014556939389, variation=1.0695890819562015e-06.
# reconstruction error=0.06430908537050041, variation=1.0601988934821893e-06.
# reconstruction error=0.0643080343900811, variation=1.0509804193037375e-06.
# reconstruction error=0.06430699246121034, variation=1.041928870765263e-06.
# reconstruction error=0.06430595942155413, variation=1.0330396562063804e-06.
# reconstruction error=0.06430493511323153, variation=1.0243083226058047e-06.
# reconstruction error=0.0643039193827153, variation=1.015730516223945e-06.
# reconstruction error=0.06430291208064057, variation=1.0073020747375372e-06.
# reconstruction error=0.06430191306175066, variation=9.990188899050567e-07.
# reconstruction error=0.06430092218468303, variation=9.908770676331224e-07.
# reconstruction error=0.06429993931191894, variation=9.828727640937007e-07.
# reconstruction error=0.06429896430961068, variation=9.75002308251094e-07.
# reconstruction error=0.0642979970474804, variation=9.672621302803108e-07.
# reconstruction error=0.06429703739873388, variation=9.596487465235448e-07.
# reconstruction error=0.06429608523987647, variation=9.521588574118445e-07.
# reconstruction error=0.06429514045070214, variation=9.44789174325833e-07.
# reconstruction error=0.06429420291411507, variation=9.375365870728514e-07.
# reconstruction error=0.06429327251602077, variation=9.303980943037304e-07.
# reconstruction error=0.06429234914527929, variation=9.233707414790793e-07.
# reconstruction error=0.06429143269357389, variation=9.164517053988908e-07.
# reconstruction error=0.06429052305528135, variation=9.096382925372071e-07.
# reconstruction error=0.06428962012747978, variation=9.029278015687536e-07.
# reconstruction error=0.06428872380972495, variation=8.96317754836562e-07.
# reconstruction error=0.06428783400408246, variation=8.898056424871958e-07.
# reconstruction error=0.06428695061494925, variation=8.833891332049593e-07.
# reconstruction error=0.06428607354903117, variation=8.770659180867835e-07.
# reconstruction error=0.06428520271523025, variation=8.708338009172367e-07.
# reconstruction error=0.0642843380245904, variation=8.646906398540599e-07.
# reconstruction error=0.06428347939016388, variation=8.586344265176793e-07.
# reconstruction error=0.06428262672703411, variation=8.526631297689491e-07.
# reconstruction error=0.06428177995212386, variation=8.467749102458733e-07.
# reconstruction error=0.06428093898427073, variation=8.409678531329234e-07.
# reconstruction error=0.06428010374395993, variation=8.352403108036199e-07.
# reconstruction error=0.06427927415347134, variation=8.295904885824434e-07.
# reconstruction error=0.06427845013666698, variation=8.240168043599505e-07.
# reconstruction error=0.06427763161898918, variation=8.185176778030545e-07.
# reconstruction error=0.06427681852740243, variation=8.130915867543553e-07.
# reconstruction error=0.06427601079032756, variation=8.077370748649226e-07.
# reconstruction error=0.06427520833752713, variation=8.024528004302312e-07.
# reconstruction error=0.0642744111001977, variation=7.972373294307111e-07.
# reconstruction error=0.06427361901072715, variation=7.920894705554238e-07.
# reconstruction error=0.06427283200279454, variation=7.870079326011137e-07.
# reconstruction error=0.06427205001127612, variation=7.819915184281712e-07.
# reconstruction error=0.06427127297218141, variation=7.770390947070549e-07.
# reconstruction error=0.06427050082261185, variation=7.721495695611758e-07.
# reconstruction error=0.06426973350071952, variation=7.673218923309744e-07.
# reconstruction error=0.0642689709456526, variation=7.625550669104753e-07.
# reconstruction error=0.06426821309762706, variation=7.578480255426845e-07.
# reconstruction error=0.06426745989766121, variation=7.531999658555444e-07.
# reconstruction error=0.06426671128774895, variation=7.486099122544498e-07.
# reconstruction error=0.06426596721077346, variation=7.440769754923915e-07.
# reconstruction error=0.06426522761038087, variation=7.396003925963512e-07.
# reconstruction error=0.06426449243108778, variation=7.351792930820888e-07.
# reconstruction error=0.06426376161809684, variation=7.308129909427974e-07.
# reconstruction error=0.06426303511746055, variation=7.265006362888737e-07.
# reconstruction error=0.06426231287583284, variation=7.222416277125054e-07.
# reconstruction error=0.06426159484062535, variation=7.180352074864782e-07.
# reconstruction error=0.06426088095991536, variation=7.138807099904554e-07.
# reconstruction error=0.0642601711823779, variation=7.097775374664828e-07.
# reconstruction error=0.064259465457365, variation=7.057250129005599e-07.
# reconstruction error=0.06425876373478524, variation=7.017225797517623e-07.
# reconstruction error=0.06425806596510561, variation=6.977696796334198e-07.
# reconstruction error=0.06425737209944203, variation=6.938656635785412e-07.
# reconstruction error=0.06425668208935031, variation=6.90010091716764e-07.
# reconstruction error=0.06425599588700895, variation=6.862023413656271e-07.
# reconstruction error=0.06425531344504778, variation=6.824419611639598e-07.
# reconstruction error=0.06425463471660256, variation=6.787284452247633e-07.
# reconstruction error=0.06425395965533208, variation=6.750612704803371e-07.
# reconstruction error=0.06425328821534662, variation=6.714399854584885e-07.
# reconstruction error=0.06425262035123806, variation=6.67864108558347e-07.
# reconstruction error=0.06425195601801222, variation=6.643332258471357e-07.
# reconstruction error=0.06425129517117359, variation=6.608468386265498e-07.
# reconstruction error=0.06425063776664065, variation=6.574045329360567e-07.
# reconstruction error=0.06424998376075344, variation=6.540058872100962e-07.
# reconstruction error=0.0642493331103094, variation=6.506504440367822e-07.
# reconstruction error=0.06424868577250126, variation=6.473378081489622e-07.
# reconstruction error=0.06424804170493775, variation=6.440675635044357e-07.
# reconstruction error=0.0642474008656343, variation=6.408393034562643e-07.
# reconstruction error=0.06424676321300173, variation=6.376526325707621e-07.
# reconstruction error=0.06424612870588206, variation=6.34507119665062e-07.
# reconstruction error=0.06424549730345067, variation=6.314024313947009e-07.
# reconstruction error=0.06424486896541218, variation=6.283380384886073e-07.
# reconstruction error=0.06424424365172175, variation=6.253136904249557e-07.
# reconstruction error=0.06424362132275267, variation=6.223289690798772e-07.
# reconstruction error=0.06424300193935494, variation=6.19383397737483e-07.
# reconstruction error=0.0642423854626913, variation=6.164766636340691e-07.
# reconstruction error=0.06424177185432021, variation=6.136083710861495e-07.
# reconstruction error=0.06424116107622976, variation=6.107780904512916e-07.
# reconstruction error=0.06424055309075298, variation=6.079854767832016e-07.
# reconstruction error=0.06423994786065448, variation=6.052300984965564e-07.
# reconstruction error=0.06423934534904766, variation=6.025116068286707e-07.
# reconstruction error=0.0642387455194568, variation=5.998295908582474e-07.
# reconstruction error=0.06423814833582102, variation=5.97183635778209e-07.
# reconstruction error=0.06423755376244894, variation=5.945733720785773e-07.
# reconstruction error=0.06423696176402825, variation=5.919984206875784e-07.
# reconstruction error=0.06423637230568975, variation=5.894583385013252e-07.
# reconstruction error=0.0642357853529358, variation=5.869527539559272e-07.
# reconstruction error=0.06423520087165348, variation=5.844812823174728e-07.
# reconstruction error=0.06423461882817316, variation=5.820434803155417e-07.
# reconstruction error=0.06423403918917986, variation=5.796389933032664e-07.
# reconstruction error=0.06423346192183393, variation=5.772673459247812e-07.
# reconstruction error=0.0642328869936467, variation=5.749281872385881e-07.
# reconstruction error=0.06423231437254076, variation=5.726211059348119e-07.
# reconstruction error=0.06423174402688027, variation=5.703456604916335e-07.
# reconstruction error=0.06423117592542564, variation=5.681014546288221e-07.
# reconstruction error=0.06423061003737884, variation=5.65888046796803e-07.
# reconstruction error=0.06423004633230614, variation=5.637050727036463e-07.
# reconstruction error=0.06422948478024558, variation=5.615520605600777e-07.
# reconstruction error=0.06422892535163352, variation=5.594286120597092e-07.
# reconstruction error=0.06422836801734795, variation=5.573342855696994e-07.
# reconstruction error=0.06422781274867655, variation=5.552686714038746e-07.
# reconstruction error=0.06422725951733738, variation=5.532313391704013e-07.
# reconstruction error=0.06422670829546388, variation=5.512218734932128e-07.
# reconstruction error=0.06422615905564073, variation=5.492398231499163e-07.
# reconstruction error=0.06422561177087552, variation=5.472847652149282e-07.
# reconstruction error=0.06422506641462712, variation=5.453562483964669e-07.
# reconstruction error=0.06422452296072838, variation=5.434538987436621e-07.
# ...
# reconstruction error=0.06380337838111629, variation=1.2373885249772343e-10.
# reconstruction error=0.06380337825749696, variation=1.2361932311133472e-10.
# reconstruction error=0.06380337813399715, variation=1.2349980760273382e-10.
# reconstruction error=0.06380337801062637, variation=1.2337078580948457e-10.
# reconstruction error=0.06380337788738649, variation=1.2323987663709346e-10.
# reconstruction error=0.06380337776428323, variation=1.2310326369391333e-10.
# reconstruction error=0.06380337764130138, variation=1.2298184692838277e-10.
# reconstruction error=0.06380337751843337, variation=1.2286800743499526e-10.
# reconstruction error=0.06380337739570578, variation=1.227275919779558e-10.
# reconstruction error=0.06380337727309959, variation=1.2260618909021304e-10.
# reconstruction error=0.06380337715061672, variation=1.224828710677528e-10.
# reconstruction error=0.063803377028261, variation=1.223557227758576e-10.
# reconstruction error=0.0638033769060096, variation=1.2225140344490626e-10.
# reconstruction error=0.06380337678393086, variation=1.2207873600900143e-10.
# reconstruction error=0.0638033766619394, variation=1.2199145860147809e-10.
# reconstruction error=0.06380337654008834, variation=1.2185105702222643e-10.
# reconstruction error=0.06380337641836249, variation=1.2172585162062433e-10.
# reconstruction error=0.06380337629675617, variation=1.2160632223423562e-10.
# reconstruction error=0.06380337617528457, variation=1.2147159667019736e-10.
# reconstruction error=0.06380337605391921, variation=1.2136536220452854e-10.
# reconstruction error=0.06380337593268855, variation=1.212306643960659e-10.
# reconstruction error=0.06380337581156983, variation=1.2111871228182025e-10.
# reconstruction error=0.0638033756906029, variation=1.2096693091656618e-10.
# reconstruction error=0.06380337556974222, variation=1.2086068257310956e-10.
# reconstruction error=0.06380337544899727, variation=1.207449557005802e-10.
# reconstruction error=0.06380337532838892, variation=1.2060834275740007e-10.
# reconstruction error=0.0638033752079039, variation=1.2048502473493983e-10.
# reconstruction error=0.0638033750875365, variation=1.203673966054808e-10.
# reconstruction error=0.06380337496730192, variation=1.2023458617616e-10.
# reconstruction error=0.06380337484717169, variation=1.2013022521184524e-10.
# reconstruction error=0.06380337472719133, variation=1.1998035898130865e-10.
# reconstruction error=0.06380337460731725, variation=1.198740828822764e-10.
# reconstruction error=0.06380337448757405, variation=1.1974320146546091e-10.
# reconstruction error=0.06380337436793142, variation=1.1964262913721768e-10.
# reconstruction error=0.06380337424843298, variation=1.194984389218945e-10.
# reconstruction error=0.06380337412905217, variation=1.1938081079243545e-10.
# reconstruction error=0.06380337400978141, variation=1.1927075993511949e-10.
# reconstruction error=0.06380337389064535, variation=1.1913606212665684e-10.
# reconstruction error=0.063803373771644, variation=1.1900135044040638e-10.
# reconstruction error=0.06380337365273561, variation=1.1890838313988183e-10.
# reconstruction error=0.06380337353395814, variation=1.1877747396749072e-10.
# reconstruction error=0.06380337341532297, variation=1.186351711313094e-10.
# reconstruction error=0.06380337329678644, variation=1.1853652781557145e-10.
# reconstruction error=0.06380337317837514, variation=1.1841129465839373e-10.
# reconstruction error=0.06380337306008528, variation=1.1828986401507535e-10.
# reconstruction error=0.06380337294192631, variation=1.1815896872047205e-10.
# reconstruction error=0.0638033728238774, variation=1.1804891786315608e-10.
# reconstruction error=0.0638033727059518, variation=1.1792559984069584e-10.
# reconstruction error=0.06380337258814005, variation=1.1781174646952053e-10.
# reconstruction error=0.06380337247045541, variation=1.1768463981098876e-10.
# reconstruction error=0.06380337235289218, variation=1.175632230454582e-10.
# reconstruction error=0.06380337223545988, variation=1.1743229999527927e-10.
# reconstruction error=0.06380337211813762, variation=1.173222630157511e-10.
# reconstruction error=0.0638033720009311, variation=1.1720652226543393e-10.
# reconstruction error=0.0638033718838422, variation=1.170888941359749e-10.
# reconstruction error=0.06380337176687473, variation=1.1696747737044433e-10.
# reconstruction error=0.0638033716500325, variation=1.168422303354788e-10.
# reconstruction error=0.06380337153330029, variation=1.1673220723373845e-10.
# reconstruction error=0.06380337141669519, variation=1.1660510057520668e-10.
# reconstruction error=0.06380337130020584, variation=1.164893459471017e-10.
# reconstruction error=0.06380337118382653, variation=1.1637930896757354e-10.
# reconstruction error=0.06380337106759142, variation=1.1623511875225034e-10.
# reconstruction error=0.06380337095145684, variation=1.1613457417958273e-10.
# reconstruction error=0.0638033708354494, variation=1.1600743976547534e-10.
# reconstruction error=0.063803370719552, variation=1.1589740278594718e-10.
# reconstruction error=0.06380337060377222, variation=1.1577977465648814e-10.
# reconstruction error=0.06380337048812337, variation=1.1564885160630922e-10.
# reconstruction error=0.06380337037257316, variation=1.1555020829057128e-10.
# reconstruction error=0.06380337025713681, variation=1.1543635491939597e-10.
# reconstruction error=0.06380337014184084, variation=1.1529596721793212e-10.
# reconstruction error=0.0638033700266625, variation=1.1517833908847308e-10.
# reconstruction error=0.06380336991159231, variation=1.1507018948808678e-10.
# reconstruction error=0.06380336979663216, variation=1.1496015250855862e-10.
# reconstruction error=0.06380336968178965, variation=1.1484251050131178e-10.
# reconstruction error=0.06380336956706856, variation=1.1472109373578121e-10.
# reconstruction error=0.06380336945247649, variation=1.1459207194253196e-10.
# reconstruction error=0.06380336933799066, variation=1.1448582359907533e-10.
# reconstruction error=0.06380336922361676, variation=1.1437389924040531e-10.
# reconstruction error=0.06380336910936621, variation=1.1425055346236945e-10.
# reconstruction error=0.06380336899523327, variation=1.1413293921069823e-10.
# reconstruction error=0.06380336888122366, variation=1.1400960731045018e-10.
# reconstruction error=0.06380336876731461, variation=1.1390904885999475e-10.
# reconstruction error=0.0638033686535232, variation=1.1379142073053572e-10.
# reconstruction error=0.06380336853985319, variation=1.1367000396500515e-10.
# reconstruction error=0.06380336842628755, variation=1.1356564300069039e-10.
# reconstruction error=0.06380336831286229, variation=1.1342525529922654e-10.
# reconstruction error=0.06380336819953761, variation=1.133246829709833e-10.
# reconstruction error=0.06380336808631157, variation=1.1322603965524536e-10.
# reconstruction error=0.06380336797322593, variation=1.130856380759937e-10.
# reconstruction error=0.06380336786025224, variation=1.1297368596174806e-10.
# reconstruction error=0.06380336774737909, variation=1.1287315526686825e-10.
# reconstruction error=0.06380336763464445, variation=1.1273464106675846e-10.
# reconstruction error=0.06380336752201038, variation=1.1263406873851523e-10.
# reconstruction error=0.06380336740947685, variation=1.1253352416584761e-10.
# reconstruction error=0.06380336729706285, variation=1.1241400865724671e-10.
# reconstruction error=0.06380336718477976, variation=1.1228308560706779e-10.
# reconstruction error=0.06380336707260482, variation=1.1217493600668149e-10.
# reconstruction error=0.06380336696053043, variation=1.1207439143401388e-10.
# reconstruction error=0.06380336684859836, variation=1.1193207472004474e-10.
# reconstruction error=0.06380336673676491, variation=1.118334452820946e-10.
# reconstruction error=0.06380336662503394, variation=1.117309716969217e-10.
# reconstruction error=0.06380336651343388, variation=1.1160006252453059e-10.
# reconstruction error=0.06380336640193056, variation=1.1150332046572231e-10.
# reconstruction error=0.0638033662905506, variation=1.1137996080989865e-10.
# reconstruction error=0.06380336617928634, variation=1.112642616929449e-10.
# reconstruction error=0.06380336606813593, variation=1.1115040832176959e-10.
# reconstruction error=0.0638033659570766, variation=1.110593284003869e-10.
# reconstruction error=0.06380336584615007, variation=1.1092653184885393e-10.
# reconstruction error=0.06380336573534495, variation=1.1080511508332336e-10.
# reconstruction error=0.0638033656246347, variation=1.1071024652586914e-10.
# reconstruction error=0.0638033655140421, variation=1.105926045186223e-10.
# reconstruction error=0.06380336540356332, variation=1.104787789030226e-10.
# reconstruction error=0.063803365293187, variation=1.1037631919563751e-10.
# reconstruction error=0.06380336518294728, variation=1.1023972013024519e-10.
# reconstruction error=0.06380336507278346, variation=1.1016382250872425e-10.
# reconstruction error=0.06380336496275245, variation=1.1003101207940347e-10.
# reconstruction error=0.06380336485283908, variation=1.0991337007215662e-10.
# reconstruction error=0.06380336474304142, variation=1.0979765707741507e-10.
# reconstruction error=0.06380336463333863, variation=1.0970278851996085e-10.
# reconstruction error=0.06380336452374588, variation=1.0959275154043269e-10.
# reconstruction error=0.06380336441427646, variation=1.0946941964018464e-10.
# reconstruction error=0.06380336430490571, variation=1.0937074856887108e-10.
# reconstruction error=0.06380336419565448, variation=1.0925123306027018e-10.
# reconstruction error=0.06380336408650948, variation=1.0914499859460136e-10.
# reconstruction error=0.06380336397747075, variation=1.0903873637335693e-10.
# reconstruction error=0.06380336386855723, variation=1.0891351709396702e-10.
# reconstruction error=0.06380336375972719, variation=1.0883004220030301e-10.
# reconstruction error=0.06380336365104515, variation=1.0868203559333267e-10.
# reconstruction error=0.06380336354244848, variation=1.085966733205268e-10.
# reconstruction error=0.06380336343396753, variation=1.0848094644799744e-10.
# reconstruction error=0.06380336332559285, variation=1.08374684226753e-10.
# reconstruction error=0.06380336321733958, variation=1.0825326746122244e-10.
# reconstruction error=0.06380336310919066, variation=1.0814892037469548e-10.
# reconstruction error=0.06380336300115749, variation=1.080331657465905e-10.
# reconstruction error=0.06380336289321538, variation=1.0794211358078343e-10.
# reconstruction error=0.063803362785389, variation=1.0782637283046625e-10.
# reconstruction error=0.06380336267767835, variation=1.077106598357247e-10.
# reconstruction error=0.06380336257005688, variation=1.0762146729348387e-10.
# reconstruction error=0.06380336246257202, variation=1.0748485435030375e-10.
# reconstruction error=0.0638033623551915, variation=1.073805211415646e-10.
# reconstruction error=0.06380336224790585, variation=1.0728565258411038e-10.
# reconstruction error=0.06380336214072645, variation=1.0717940424065375e-10.
# reconstruction error=0.06380336203367795, variation=1.0704849506826264e-10.
# reconstruction error=0.06380336192671673, variation=1.069612176607393e-10.
# reconstruction error=0.06380336181986747, variation=1.0684926554649365e-10.
# reconstruction error=0.06380336171313201, variation=1.0673545380868177e-10.
# reconstruction error=0.06380336160650853, variation=1.0662348781664832e-10.
# reconstruction error=0.06380336149998747, variation=1.0652105586483884e-10.
# reconstruction error=0.06380336139356507, variation=1.0642239867131309e-10.
# reconstruction error=0.06380336128725843, variation=1.0630664404320811e-10.
# reconstruction error=0.06380336118106751, variation=1.0619091717067874e-10.
# reconstruction error=0.06380336107496576, variation=1.0610175238401354e-10.
# reconstruction error=0.06380336096897975, variation=1.0598601163369636e-10.
# reconstruction error=0.06380336086311135, variation=1.0586839738202514e-10.
# reconstruction error=0.06380336075733405, variation=1.0577730358285464e-10.
# reconstruction error=0.06380336065167436, variation=1.0565968933118342e-10.
# reconstruction error=0.06380336054610004, variation=1.0557431318058974e-10.
# reconstruction error=0.06380336044065665, variation=1.0544339013041082e-10.
# reconstruction error=0.06380336033532141, variation=1.0533524053002452e-10.
# reconstruction error=0.06380336023006965, variation=1.0525176563636052e-10.
# reconstruction error=0.0638033601249431, variation=1.0512654635697061e-10.
# reconstruction error=0.063803360019919, variation=1.0502410052737332e-10.
# reconstruction error=0.06380335991499736, variation=1.0492164081998823e-10.
# reconstruction error=0.06380335981019905, variation=1.0479830891974018e-10.
# reconstruction error=0.06380335970547663, variation=1.0472242517600705e-10.
# reconstruction error=0.0638033596008794, variation=1.0459721977440495e-10.
# reconstruction error=0.06380335949637327, variation=1.0450613985302226e-10.
# reconstruction error=0.06380335939200184, variation=1.0437142816677181e-10.
# reconstruction error=0.0638033592877082, variation=1.0429364316610901e-10.
# reconstruction error=0.06380335918351891, variation=1.0418928220179424e-10.
# reconstruction error=0.06380335907944155, variation=1.0407735784312422e-10.
# reconstruction error=0.06380335897547046, variation=1.0397109562187978e-10.
# reconstruction error=0.0638033588716094, variation=1.0386105864235162e-10.
# reconstruction error=0.06380335876785269, variation=1.0375671155582467e-10.
# reconstruction error=0.06380335866420032, variation=1.0365236446929771e-10.
# reconstruction error=0.06380335856063714, variation=1.0356318580484469e-10.
# reconstruction error=0.06380335845718968, variation=1.0344745893231533e-10.
# reconstruction error=0.06380335835384847, variation=1.033412105888587e-10.
# reconstruction error=0.06380335825060782, variation=1.0324065213840328e-10.
# reconstruction error=0.06380335814745444, variation=1.0315337473087993e-10.
# reconstruction error=0.0638033580444225, variation=1.0303194408756156e-10.
# reconstruction error=0.06380335794150628, variation=1.0291621721503219e-10.
# reconstruction error=0.06380335783867354, variation=1.0283274232136819e-10.
# reconstruction error=0.06380335773595465, variation=1.0271888895019288e-10.
# reconstruction error=0.0638033576333401, variation=1.0261455574145373e-10.
# reconstruction error=0.06380335753082421, variation=1.0251588467014017e-10.
# reconstruction error=0.06380335742840697, variation=1.0241724135440222e-10.
# reconstruction error=0.06380335732609978, variation=1.0230719049708625e-10.
# reconstruction error=0.06380335722390643, variation=1.0219335100369875e-10.
# reconstruction error=0.06380335712180225, variation=1.0210417233924574e-10.
# reconstruction error=0.06380335701978913, variation=1.0201312017343867e-10.
# reconstruction error=0.06380335691789935, variation=1.0188978827319062e-10.
# reconstruction error=0.06380335681609683, variation=1.0180251086566727e-10.
# reconstruction error=0.06380335671440247, variation=1.0169436126528097e-10.
# reconstruction error=0.06380335661281054, variation=1.015919293134715e-10.
# reconstruction error=0.06380335651133058, variation=1.0147996332143805e-10.
# reconstruction error=0.06380335640994546, variation=1.0138512251955945e-10.
# reconstruction error=0.06380335630864763, variation=1.0129783123424829e-10.
# reconstruction error=0.06380335620746552, variation=1.0118210436171893e-10.
# reconstruction error=0.06380335610637829, variation=1.0108723580426471e-10.
# reconstruction error=0.0638033560053935, variation=1.0098478997466742e-10.
# reconstruction error=0.06380335590453015, variation=1.0086334545356124e-10.
# reconstruction error=0.06380335580374456, variation=1.0078558820847405e-10.
# reconstruction error=0.06380335570308232, variation=1.006622424304382e-10.
# reconstruction error=0.06380335560250734, variation=1.0057497890070266e-10.
# reconstruction error=0.06380335550202534, variation=1.004819977223903e-10.
# reconstruction error=0.06380335540164768, variation=1.0037766451365115e-10.
# reconstruction error=0.06380335530140095, variation=1.0024672758568443e-10.
# reconstruction error=0.06380335520121112, variation=1.0018982865567239e-10.
# reconstruction error=0.06380335510112944, variation=1.0008167905528609e-10.
# reconstruction error=0.06380335500116349, variation=9.996595218275672e-11.
# converged in 10365 iterations.

# %% [markdown]
# Let's take a closer look at the non-negative Kruskal decomposition results.

# %%
nonneg_3_rand
# Out:
# (weights, factors) : rank-3 KruskalTensor of shape (3, 62, 888)

# %%
# Shape of tensor
nonneg_3_rand.shape
# Out:
# (3, 62, 888)

# %%
# Weight for each factor
nonneg_3_rand.weights
# Out:
# array([4270.49497783, 4271.63098325, 4272.10317884])

# %%
# Shape of each factor
[fac.shape for fac in nonneg_3_rand.factors]
# Out:
# [(3, 3), (62, 3), (888, 3)]

# %% [markdown]
# Now we try to reconstruct the data from the factors:

# %%
# Reconstruction
full_tensor_3 = tl.kruskal_to_tensor(regular_3_rand)
full_tensor_nonneg_3 = tl.kruskal_to_tensor(nonneg_3_rand)

# %%
# Double check the shape of the reconstructed tensor
full_tensor_3.shape
# Out:
# (3, 62, 888)

# %% [markdown]
# ### Check full reconstruction

# %% [markdown]
# Let's check how the reconstruction compare between the regular and non-negative versions of Kruskal decomposition.

# %%
# Assemble DataArrays to make plotting easier
# regular Kruskal
recon_regular_3 = []
for f in range(3):
    recon_regular_3.append(tl.unfold(tl.tensor(full_tensor_3[f,:,:].reshape((62,37,24))).squeeze()+
                                     sonar_tensor.min(), mode=1)[::-1,:])
recon_regular_3 = xr.DataArray(np.array(recon_regular_3), 
                    coords=[('frequency', frequency), 
                            ('depth', depth), 
                            ('ping_time', p_time_reduce)])
# non-negative Kruskal
recon_nonneg_3 = []
for f in range(3):
    recon_nonneg_3.append(tl.unfold(tl.tensor(full_tensor_nonneg_3[f,:,:].reshape((62,37,24))).squeeze()+
                                    sonar_tensor.min(), mode=1)[::-1,:])
recon_nonneg_3 = xr.DataArray(np.array(recon_nonneg_3), 
                              coords=[('frequency', frequency), 
                                      ('depth', depth), 
                                      ('ping_time', p_time_reduce)])

# %%
def compare_reconstruction(freq):
    fig,ax = plt.subplots(3,1,figsize=(14,5.5),sharex=True)
    im = MVBS_pcp_reduce.sel(frequency=freq).\
        plot(ax=ax[0], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    ax[0].set_title('Data at %d kHz' % (freq/1000))
    recon_regular_3.sel(frequency=freq).\
        plot(ax=ax[1], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    ax[1].set_title('Regular Kruskal at %d kHz' % (freq/1000))
    recon_nonneg_3.sel(frequency=freq).\
        plot(ax=ax[2], vmin=-80, vmax=-40, cmap='Spectral_r', add_colorbar=False, yincrease=False)
    ax[2].set_title('Non-negative Kruskal at %d kHz' % (freq/1000))

    ax[0].set_xlabel('')
    ax[1].set_xlabel('')
    ax[2].xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
    [ax[c].set_ylabel('Depth (m)', fontsize=14) for c in range(3)]
    [ax[c].tick_params(labelsize=12) for c in range(3)]
    ax[2].set_xlabel('Time', fontsize=14)
    plt.setp(ax[2].get_xticklabels(), rotation=0, horizontalalignment='center')

    plt.subplots_adjust(hspace=0.25)

    fig.subplots_adjust(right=0.95)
    cbar_ax = fig.add_axes([0.96, 0.125, 0.01, 0.755])  # [left, bottom, width, height]
    cbar = fig.colorbar(im, cax=cbar_ax)
    cbar.set_ticks(np.arange(-80, -39, 10))

    plt.show()
    return fig

# %% [markdown]
# ### Full reconstruction comparison at 38 kHz

# %%
fig = compare_reconstruction(38000)
fig.savefig(os.path.join(fig_save_path,'recon_cmp_38kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# The patterns seem broadly similar, althought it is noticeable that the dark (low echo energy) patches are darker for regular Kruskal around Sep-26 to Oct-01.

# %% [markdown]
# ### Full reconstruction comparison at 120 kHz

# %%
fig = compare_reconstruction(120000)
fig.savefig(os.path.join(fig_save_path,'recon_cmp_120kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# As in the 38 kHz reconstruction results, the darker patches around day 46-51 are darker for regular Kruskal.

# %% [markdown]
# ### Full reconstruction comparison at 200 kHz

# %%
fig = compare_reconstruction(200000)
fig.savefig(os.path.join(fig_save_path,'recon_cmp_200kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ## Check individual components

# %% [markdown]
# To figure out which factor corresponds to which dimension, let's check the size of the factors:

# %%
[fac.shape for fac in nonneg_3_rand.factors]
# Out:
# [(3, 3), (62, 3), (888, 3)]

# %% [markdown]
# We know that factor 0 corresponds with decomposition along `frequency`, factor 1 with `day of observation`, and factor 2 with `pixels in daily echogram`.

# %% [markdown]
# ### Non-negative Kruskal decomposition:

# %%
nonneg_day_activation = xr.DataArray(
    nonneg_3_rand.factors[1].T, 
    coords=[('component', range(3)), ('date', pd.date_range('2015-08-17', periods=62))])

# %%
title_fontsize=16
axislabel_fontsize=16
ticklabel_fontsize=14
subfig_fontsize=22

freq_ylim = (-0.05, 0.85)


fig = plt.figure(figsize=(10,8))
gs_top = fig.add_gridspec(1,3, bottom=0.73)
gs_middle = fig.add_gridspec(1,3, top=0.57, bottom=0.39)
gs_bottom = fig.add_gridspec(1,1, bottom=0, top=0.25)


for ifac in range(3):

    # Daily echogram
    ax = fig.add_subplot(gs_top[0, ifac])
    im = ax.imshow(nonneg_3_rand.factors[2][:,ifac].reshape((37,24))[::-1,:],
                   aspect='auto',cmap='Spectral_r')
    ax.set_title('Component #%d'% ifac, fontsize=title_fontsize)
    ax.set_xticks(np.arange(0,25,6))
    ax.set_yticks(range(0,37,18))
    ax.set_yticklabels((np.arange(0,37,18)+1)*depth_bin_size)
    ax.set_xlabel('Hour', fontsize=axislabel_fontsize)
    if ifac==0:
        ax.set_ylabel('Depth (m)', fontsize=axislabel_fontsize)
    else:
        ax.set_yticklabels('')
    ax.tick_params(labelsize=10)
    pos = ax.get_position()
    new_ax = [pos.x0, pos.y0-0.09]  # bottom-left starting point for color axis        
    cbar_ax = fig.add_axes([new_ax[0], new_ax[1], pos.width, 0.02])  # [left, bottom, width, height]
    cbar = fig.colorbar(im, cax=cbar_ax, orientation='horizontal')
    cbar.ax.tick_params(labelsize=ticklabel_fontsize)
    if ifac==0:
        fig.text(x=-0.35,y=1.05,s='A',transform=ax.transAxes, 
                 fontsize=subfig_fontsize, fontweight='bold')
    
    # Frequency
    ax = fig.add_subplot(gs_middle[0, ifac])
    ax.plot(nonneg_3_rand.factors[0][:,ifac],'o-', linewidth=3, 
            markersize=8, color='C%d'%ifac,
            label='Comp #%d'%ifac)
    ax.set_xticks(range(3))
    ax.set_xticklabels([38,120,200], fontsize=axislabel_fontsize)
    if ifac==0:
        ax.set_ylabel('Relative\nstrength', fontsize=axislabel_fontsize)
    else:
        ax.set_yticklabels('')
    ax.tick_params(labelsize=ticklabel_fontsize)
    ax.set_xlabel('Frequency (kHz)', fontsize=axislabel_fontsize)
    ax.set_ylim(freq_ylim)
    ax.legend(fontsize=axislabel_fontsize, loc='lower right')
    if ifac==0:
        fig.text(x=-0.35,y=1.00,s='B',transform=ax.transAxes, 
                 fontsize=subfig_fontsize, fontweight='bold')
    
# Activation
ax = fig.add_subplot(gs_bottom[0, :])
hl = nonneg_day_activation.plot.line(ax=ax, x='date', linewidth=3, label='')
ax.legend()  # have to call this to supress labels
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
ax.tick_params(labelsize=ticklabel_fontsize)
plt.setp(ax.get_xticklabels(), rotation=0, horizontalalignment='center')
ax.set_xlim([datetime.date(2015, 8, 17), datetime.date(2015, 10, 17)])
ax.set_title('Activation across day', fontsize=18)
ax.set_ylabel('Relative strength', fontsize=axislabel_fontsize)
ax.set_xlabel('Time',fontsize=axislabel_fontsize)    
fig.text(x=-0.106,y=1.03,s='C',transform=ax.transAxes, 
         fontsize=subfig_fontsize, fontweight='bold')

plt.subplots_adjust(hspace=0.5)

fig.savefig(os.path.join(fig_save_path,'components_all.png'),
        dpi=150, bbox_inches = 'tight', pad_inches = 0)
# Out:
# No handles with labels found to put in legend.

# %%
fig,ax = plt.subplots(1,3,figsize=(10,2.5))
for i in range(3):
    im = ax[i].imshow(nonneg_3_rand.factors[2][:,i].reshape((37,24))[::-1,:],
                      aspect='auto',cmap='Spectral_r')
    ax[i].set_title('Component %d'% i, fontsize=14)
    ax[i].set_xticks(np.arange(0,25,6))
    ax[i].set_yticks(range(0,37,18))
    ax[i].set_yticklabels((np.arange(0,37,18)+1)*depth_bin_size)
    ax[i].set_xlabel('Hour (kHz)', fontsize=14)
    if ax[i].is_first_col():
        ax[i].set_ylabel('Depth (m)', fontsize=14)
    fig.colorbar(im, ax=ax[i])
plt.tight_layout()
plt.show()

fig.savefig(os.path.join(fig_save_path,'component_daily_echogram.png'), dpi=150)

# %%
fig = plt.figure(figsize=(10,2.5), constrained_layout=True)
gs = fig.add_gridspec(1, 3)

ax1 = fig.add_subplot(gs[0, 0])
ax1.plot(nonneg_3_rand.factors[0],'o-',linewidth=3,markersize=8)
ax1.set_xticks(range(3))
ax1.set_xticklabels([38,120,200], fontsize=12)
ax1.set_xlabel('Frequency (kHz)', fontsize=14)
ax1.set_ylabel('Relative strength', fontsize=14)
ax1.tick_params(labelsize=12)

fig.savefig(os.path.join(fig_save_path,'component_freq.png'), dpi=150)

# %%
fig = plt.figure(figsize=(12,2.5), constrained_layout=True)
gs = fig.add_gridspec(1, 3)

ax2 = fig.add_subplot(gs[0, :2])
hl = nonneg_day_activation.plot.line(ax=ax2, x='date', linewidth=3, label='')
ax2.legend()  # have to call this to supress labels
ax2.set_ylabel('Relative strength', fontsize=14)
ax2.set_xlabel('Time',fontsize=14)
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
ax2.tick_params(labelsize=12)
plt.setp(ax2.get_xticklabels(), rotation=0, horizontalalignment='center')
ax2.set_xlim([datetime.date(2015, 8, 17), datetime.date(2015, 10, 17)])

plt.show()

fig.savefig(os.path.join(fig_save_path,'component_activation.png'), dpi=150)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Combine pairs of factors

# %% [markdown]
# To get some intuition of what the individual components represent, here we do partial reconstruction of the components using only 2 out of the 3 dimensions.

# %%
import itertools

# %%
# Khatri-kao product to combine the factors
kr_nn_patterns = []
kr_nn_combs = []
for x,y in itertools.combinations(range(3),2):
    kr_nn_patterns.append((x,y))
    kr_nn_combs.append(khatri_rao((nonneg_3_rand.factors[x],nonneg_3_rand.factors[y])))

# %%
sonar_tensor.shape
# Out:
# (3, 62, 888)

# %%
kr_nn_patterns
# Out:
# [(0, 1), (0, 2), (1, 2)]

# %%
[x.shape for x in kr_nn_combs]
# Out:
# [(186, 3), (2664, 3), (55056, 3)]

# %%
37*24
# Out:
# 888

# %%
888*62
# Out:
# 55056

# %% [markdown]
# ### Combine frequency and daily echogram pattern

# %%
title_fontsize=16
axislabel_fontsize=16
ticklabel_fontsize=14
subfig_fontsize=22

fig,ax_all = plt.subplots(3,3,figsize=(10,6), sharex=True, sharey=True)
fig.subplots_adjust(wspace=0.1, hspace=0.1)

for ifac in range(3):  # loop through factors
    # Get daily echogram pattern and value range
    fac_echogram = tl.unfold(tl.tensor(kr_nn_combs[1][:,ifac].reshape(3,37,24)[:,::-1,:]),mode=2).T
    zmax = fac_echogram.max()
    zmin = fac_echogram.min()
#     fac_echogram = (fac_echogram-zmin)/(zmax-zmin)
    for ifreq, freq in enumerate(frequency):    # loop through frequency
        ax = ax_all[ifreq, ifac]
        im = ax.imshow(fac_echogram[ifreq*37+np.arange(0,37,1),:],aspect='auto', vmax=zmax, vmin=zmin, 
                       cmap='Spectral_r')
        ax.set_yticks(range(0,37,18))
        ax.set_yticklabels((np.arange(0,37,18)+1)*depth_bin_size)
        ax.set_xticks(np.arange(0,25,6))
        if ifreq==0:
            ax.set_title('Component %d'% ifac, fontsize=title_fontsize)
        if ifac==0 and ifreq==1:
            ax.set_ylabel('Depth (m)', fontsize=axislabel_fontsize)
        ax.tick_params(labelsize=ticklabel_fontsize)
        if ifreq==2:
            pos = ax.get_position()
            new_ax = [pos.x0, pos.y0-0.14]  # bottom-left starting point for color axis        
            cbar_ax = fig.add_axes([new_ax[0], new_ax[1], pos.width, 0.02])  # [left, bottom, width, height]
            cbar = fig.colorbar(im, cax=cbar_ax, orientation='horizontal')
            cbar_ax.tick_params(labelsize=ticklabel_fontsize)
            if ifac==1:
                ax.set_xlabel('Hour (kHz)', fontsize=axislabel_fontsize)
plt.show()

fig.savefig(os.path.join(fig_save_path,'combine_freq_daily_echogram.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Combine frequency-dependent echogram pattern and day of activation

# %% [markdown]
# We combine the echogram pattern factors and their daily activation using Khatri-Rao product:

# %%
kr_nn_cube_all = khatri_rao((nonneg_3_rand.factors[0],
                             nonneg_3_rand.factors[1],
                             nonneg_3_rand.factors[2]))

# %% [markdown]
# Let's cehck the shapes of the combined factors and make sure we understand how to reshape them back to the partially reconstructed echograms we are looking for.

# %%
L_sep_reduce.shape
# Out:
# (3, 62, 37, 24)

# %%
kr_nn_cube_all.shape
# Out:
# (165168, 3)

# %%
3*62*37*24
# Out:
# 165168

# %%
kr_nn_cube_all_fac = [nonneg_3_rand.weights[comp]*kr_nn_cube_all[:,comp].reshape(L_sep_reduce.shape) 
                      for comp in range(3)]

# %%
kr_nn_cube_all_fac[0].shape
# Out:
# (3, 62, 37, 24)

# %% [markdown]
# We reconstruct DataArrays as before to facilitate plotting:

# %%
partial_38 = []
partial_120 = []
partial_200 = []
for fac in range(3):
    partial_38.append(tl.unfold(tl.tensor(kr_nn_cube_all_fac[fac][0,:,:,:].squeeze()[:,::-1,:]),mode=1))
    partial_120.append(tl.unfold(tl.tensor(kr_nn_cube_all_fac[fac][1,:,:,:].squeeze()[:,::-1,:]),mode=1))
    partial_200.append(tl.unfold(tl.tensor(kr_nn_cube_all_fac[fac][2,:,:,:].squeeze()[:,::-1,:]),mode=1))

# %%
np.array(partial_38).shape
# Out:
# (3, 37, 1488)

# %%
partial_38 = xr.DataArray(np.array(partial_38), 
                    coords=[('component', range(3)), ('depth', depth), ('ping_time', p_time_reduce)])
partial_120 = xr.DataArray(np.array(partial_120), 
                    coords=[('component', range(3)), ('depth', depth), ('ping_time', p_time_reduce)])
partial_200 = xr.DataArray(np.array(partial_200), 
                    coords=[('component', range(3)), ('depth', depth), ('ping_time', p_time_reduce)])

# %% [markdown]
# Now we are ready to check how the factors are combined to form the long-term echogram at a particular frequency.

# %%
sonar_tensor.min()
# Out:
# -94.83359325945042

# %%
def check_partial_echogram(freq, partial):
    title_fontsize=16
    axislabel_fontsize=16
    ticklabel_fontsize=14
    subfig_fontsize=22

    fig = plt.figure(figsize=(10,6))
    gs_top = fig.add_gridspec(1,1, bottom=0.70)
    gs = fig.add_gridspec(3,1, bottom=0.1, top=0.64)

    V = MVBS_pcp_reduce-sonar_tensor.min()
    vmin_data = -80+95
    vmax_data = -40+95
    ax_data = fig.add_subplot(gs_top[0,0])
    im = V.sel(frequency=freq).plot(ax=ax_data, cmap='Spectral_r', vmin=vmin_data, vmax=vmax_data,
                                    yincrease=False, add_colorbar=False)
    ax_data.set_title('Data at %d kHz' % (freq/1000), fontsize=title_fontsize)
    ax_data.set_xlabel('')
    ax_data.set_xticklabels('')
    ax_data.set_ylabel('Depth (m)', fontsize=axislabel_fontsize)
    ax_data.tick_params(labelsize=ticklabel_fontsize)
    plt.setp(ax_data.get_xticklabels(), rotation=0, horizontalalignment='center')
    
    pos = ax_data.get_position()
    new_ax = [pos.x0+pos.width, pos.y0]  # bottom-left starting point for color axis        
    cbar_ax = fig.add_axes([new_ax[0]+0.012, new_ax[1], 0.01, 0.18])  # [left, bottom, width, height]
    cbar = fig.colorbar(im, cax=cbar_ax)  
    cbar.ax.tick_params(labelsize=ticklabel_fontsize)
    cbar.ax.set_title('Sv (dB)', fontsize=ticklabel_fontsize, ha='center')

    vmin = 0 #partial.min().values
    vmax = vmax_data #partial.max().values
    for ifac in range(3):
        ax = fig.add_subplot(gs[ifac,0])
        partial.sel(component=ifac).plot(ax=ax, cmap='Spectral_r', vmin=vmin, vmax=vmax,
                                         yincrease=False, add_colorbar=False)
        ax.tick_params(labelsize=ticklabel_fontsize)
        ax.set_ylabel('')
        ax.set_xlabel('')
        ax.set_title('')
        ax.set_xticklabels('')

        if ifac==0:
            ax.set_title('Components at %d kHz' % (freq/1000), fontsize=title_fontsize)
        if ifac==1:
            ax.set_ylabel('Depth (m)', fontsize=axislabel_fontsize)
        if ifac==2:
            ax.xaxis.set_major_formatter(mdates.DateFormatter('%b-%d'))
            ax.set_xlabel('Time', fontsize=axislabel_fontsize)
            plt.setp(ax.get_xticklabels(), rotation=0, horizontalalignment='center')
            
        ax.annotate('Component %d'%ifac, 
                    xy=(0.015,0.15), xycoords='axes fraction', 
                    fontsize=ticklabel_fontsize, color='k', 
                    bbox=dict(facecolor='w', edgecolor=None, alpha=0.8))

    pos = ax.get_position()
    new_ax = [pos.x0+pos.width, pos.y0]  # bottom-left starting point for color axis        
    cbar_ax = fig.add_axes([new_ax[0]+0.012, new_ax[1]+0.1, 0.01, 0.34])  # [left, bottom, width, height]
    cbar = fig.colorbar(im, cax=cbar_ax)  
    cbar.ax.tick_params(labelsize=ticklabel_fontsize)

    fig.subplots_adjust(hspace=0.1)
    plt.show()
    
    return fig

# %% [markdown]
# ### Frequency-dependent component contribution at 38 kHz

# %%
# Partial reconstruction at 38 kHz
fig = check_partial_echogram(38000, partial_38)
fig.savefig(os.path.join(fig_save_path,'combine_all_38kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Frequency-dependent component contribution at 120 kHz

# %%
# Partial reconstruction at 120 kHz
fig = check_partial_echogram(120000, partial_120)
fig.savefig(os.path.join(fig_save_path,'combine_all_120kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)

# %% [markdown]
# ### Frequency-dependent component contribution at 200 kHz

# %%
# Partial reconstruction at 200 kHz
fig = check_partial_echogram(200000, partial_200)
fig.savefig(os.path.join(fig_save_path,'combine_all_200kHz.png'),
            dpi=150, bbox_inches = 'tight', pad_inches = 0)
